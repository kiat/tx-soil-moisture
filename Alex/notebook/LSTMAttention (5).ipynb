# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# 0 = all messages are logged (default behavior)
# 1 = INFO messages are not printed
# 2 = INFO and WARNING messages are not printed
# 3 = INFO, WARNING, and ERROR messages are not printed

import datetime

import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
#from google.colab import drive
#drive.mount('/content/gdrive')

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

#import warnings
# https://stackoverflow.com/questions/15777951/how-to-suppress-pandas-future-warning
#warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.simplefilter(action='ignore', category=Warning)

tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(0)

import logging
tf.get_logger().setLevel(logging.ERROR)

# https://stackoverflow.com/questions/65697623/tensorflow-warning-found-untraced-functions-such-as-lstm-cell-6-layer-call-and
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#   print('Not connected to a GPU')
# else:
#   print(gpu_info)

# %%
dfs = {}

df = pd.read_csv('/content/Station1_Revised_Final_Data.csv', sep=",", parse_dates=["Unnamed: 0"], index_col="Unnamed: 0")
dfs['Station1'] = df
# for index in range(0, 6):
#   df = pd.read_csv('Station' + str(index + 1) + '_simulated_cleaned_merged_data.csv', sep=",", parse_dates=["Unnamed: 0"], index_col="Unnamed: 0")
#   dfs['Station' + str(index + 1)] = df
#   df.index = pd.to_datetime(df.index)

print(df.isna().sum())

# %%
df.describe().transpose()

# %%
import numpy as np
import pandas as pd

def engineer_data(dfs, boolean):
    # Constants for day and year calculations
    day = 24 * 60 * 60
    year = 365.2425 * day

    for station, df in dfs.items():
        # Drop rows with NaN values to ensure clean data
        df = df.dropna()

        # Extract windspeed and wind direction
        wv = df['Windspeed']
        wd_rad = np.deg2rad(df['Winddirection'])  # Convert degrees to radians

        # Ensure the index is in datetime format
        df.index = pd.to_datetime(df.index)

        # Convert timestamp index to seconds
        timestamp_s = df.index.map(pd.Timestamp.timestamp)

        # Extract latitude and longitude
        lat = np.deg2rad(df['Latitude'])  # Convert latitude to radians
        lon = np.deg2rad(df['Longitude'])  # Convert longitude to radians

        # Engineer wind components

        # print("HELLO", wv * np.cos(wd_rad))
        # print("AHHHHH",wd_rad)

        if boolean:
          df['Wx'] = wv * np.cos(wd_rad)
          df['Wy'] = wv * np.sin(wd_rad)

        # Engineer time-based cyclic features
        df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
        df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
        df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
        df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

        # Engineer Cartesian coordinates for latitude and longitude
        df['x_cord'] = np.cos(lat) * np.cos(lon)
        df['y_cord'] = np.cos(lat) * np.sin(lon)
        df['z_cord'] = np.sin(lat)

        # Update the DataFrame in the dictionary
        dfs[station] = df

    return dfs

# %%
engineer_data(dfs, False)

engineer_data(dfs, True)

# %%
dfs['Station1'].describe().transpose()

# %%
def scale_data(dfs):
    for station, df in dfs.items():
        cur_df = df.copy()
        d_sin = cur_df.pop("Day sin")
        d_cos = cur_df.pop("Day cos")
        y_sin = cur_df.pop("Year sin")
        y_cos = cur_df.pop("Year cos")
        x = cur_df.pop("x_cord")
        y = cur_df.pop("y_cord")
        z = cur_df.pop("z_cord")
        scaler = MinMaxScaler()
        scaled_df = pd.DataFrame(data=scaler.fit_transform(cur_df), columns=cur_df.columns, index=cur_df.index)
        scaled_df["Day sin"] = d_sin.values
        scaled_df["Day cos"] = d_cos.values
        scaled_df["Year sin"] = y_sin.values
        scaled_df["Year cos"] = y_cos.values
        scaled_df["x_cord"] = x.values
        scaled_df["y_cord"] = y.values
        scaled_df["z_cord"] = z.values
        dfs[station] = scaled_df

# %%
scale_data(dfs)

# %%
#Definitions
TARGET_COL = "SWC_5"
TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.2
WINDOW_SIZE = 24 * 7
SHIFT_AMT = 10
PAT = 20
MAX_EPOCHS = 25

# %%
def split(df, target_col=TARGET_COL, train_split = TRAIN_SPLIT, val_split = VAL_SPLIT):
  print(df.columns)
  target_idx = df.columns.get_loc(target_col)
  train_set = df[ : int(len(df) * train_split)].values
  val_set = df[int(len(df) * train_split) : int(len(df) * (train_split + val_split))].values
  test_set = df[int(len(df) * (train_split + val_split)) :].values
  return (train_set, val_set, test_set, target_idx)

# %%
def generate_windows(data, window_size=24, shift=24, target_idx=0):
    labels = data[:, target_idx]

    X = []
    y = []
    for i in range(len(data) - window_size - shift):
        # get window based on input width
        window = data[i : i + window_size]
        window_label = labels[i + window_size + shift]

        X.append(window)
        y.append(window_label)

    # in new dataset, each element is a data window, and window label is single value
    return np.array(X), np.array(y)


# given data and its labels, divide the data into batches of size batch_size
def generate_batches(X, y, batch_size=32):
    # divides data into batches, drops any remainder batches smaller than specified batch size.
    # allows models to run with any batch size
    tf_dataset = tf.data.Dataset.from_tensor_slices((X, y))
    tf_dataset = tf_dataset.repeat().batch(batch_size=batch_size, drop_remainder=True)

    # tf_dataset repeats indefinitely, need to compute number of step updates to complete 1 epoch
    steps_per_epoch = len(X) // batch_size

    return (tf_dataset, steps_per_epoch)

# %%
def preprocess_data(df):
    # data cleaning and feature engineering
    train_set, val_set, test_set, target_idx = split(df)


    # create window data for each dataset
    X_train, y_train = generate_windows(train_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)
    X_val, y_val = generate_windows(val_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)
    X_test, y_test = generate_windows(test_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)

    return (X_train, y_train, X_val, y_val, X_test, y_test)

# %%
cur_df = dfs["Station1"]

BATCH_SIZE = 128
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data(cur_df)

# divide each dataset into batched version to feed to models
train_dataset, train_steps = generate_batches(X_train, y_train, batch_size=BATCH_SIZE)
val_dataset, val_steps = generate_batches(X_val, y_val, batch_size=BATCH_SIZE)
test_dataset, test_steps = generate_batches(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# Index(['Ppt', 'SWC_5', 'SWC_10', 'SWC_20', 'SWC_50', 'T_5', 'T_10', 'T_20',
#        'T_50', 'Tair', 'RH', 'Windspeed', 'Winddirection', 'Srad', 'Latitude',
#        'Longitude', 'Wx', 'Wy', 'Day sin', 'Day cos', 'Year sin', 'Year cos',
#        'x_cord', 'y_cord', 'z_cord'],
#       dtype='object')

# %%
def compile_and_fit(model, data, steps_per_epoch, val_data, val_steps, model_name='model/', patience=20, max_epochs=MAX_EPOCHS, batch_size=32):
    # stop running epochs if the loss stops improving for patience number of epochs
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')

    # store the best model on disk to be loaded later without having to re-fit
    # allows you to load models from disc
    ckpt = tf.keras.callbacks.ModelCheckpoint(model_name + ".keras", save_best_only=True)

    model.compile(loss=tf.keras.losses.MeanSquaredError(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])

    history = model.fit(data,
                        epochs=max_epochs,
                        callbacks=[ckpt, early_stopping],
                        validation_data=val_data,
                        validation_steps=val_steps,
                        shuffle=False,
                        batch_size=batch_size,
                        steps_per_epoch = steps_per_epoch)

    return history

# %%
preds = {}

def plot_single_pred(model, name, dataset, data_steps, y, batch_size=32, shift=24):
    forecast = model.predict(dataset, batch_size=batch_size, steps=data_steps)
    preds[name] = forecast
    if len(forecast.shape) == 3:
        print("asd")
        forecast = forecast[:, 0, 0]
    elif len(forecast.shape) == 2:
        forecast = forecast[:, 0]

  #delete later
    time_indices = np.arange(0, len(forecast) * shift, shift)

    plt.figure(figsize=(10, 6))
    plot_data = {"Predictions": forecast, "Actual": y}

    plt.plot(plot_data["Actual"])
    plt.plot(plot_data["Predictions"])

    plt.legend(("Actual", "Predictions"))

    return plot_data

    # plt.figure(figsize=(10, 6))

    # # Plot actual values on a continuous hourly scale
    # plt.plot(np.arange(len(y)), y, label="Actual")

    # # Plot predictions at 24-hour intervals using time_indices
    # plt.plot(time_indices, forecast, label="Predictions")

    # plt.xlabel("Time (in hours)")
    # plt.ylabel("Value")
    # plt.legend()
    # plt.title(f"Actual vs Predicted ({name}) with 24-Hour Shift")

    # plt.show()

# %%
lstm_model = tf.keras.models.Sequential([
    # tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(32, return_sequences=False),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

# %%
bi_lstm_model = tf.keras.models.Sequential([
    # tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=False)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh'),
])

# %%
# !pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-self-attention) (1.26.4)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=8efd21d272e95ee49618ebd95f304427d762dd7cf81dd77b5c7bc2fcf8582a42
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
#LSTM with an attention layer -
# https://stackoverflow.com/questions/58966874/adding-attention-on-top-of-simple-lstm-layer-in-tensorflow-2-0
# https://pypi.org/project/keras-self-attention/

from keras_self_attention import SeqSelfAttention


lstm_model_with_attention = tf.keras.models.Sequential([
    # tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(32, return_sequences=True),  # Set return_sequences=True for attention
    SeqSelfAttention(attention_activation='softmax'),  # Add attention layer
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

# %%
#biLSTM with an attention layer

bi_lstm_model_with_attention = tf.keras.models.Sequential([
    # tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),  # Set return_sequences=True for attention
    SeqSelfAttention(attention_activation='softmax'),  # Add attention layer
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

# %%
loss_by_epoch = {}
val_performance = {}
performance = {}

# %%
#uncessary models

# # https://www.tensorflow.org/tutorials/structured_data/time_series#baseline

# linear_model = tf.keras.Sequential([
#     tf.keras.layers.Dense(units=1)
# ])


# dense_model = tf.keras.Sequential([
#     tf.keras.layers.Dense(units=64, activation='relu'),
#     tf.keras.layers.Dense(units=32, activation='relu'),
#     tf.keras.layers.Dense(units=1)
# ])


# cnn_model = tf.keras.Sequential([
#     tf.keras.layers.Conv1D(filters=32, kernel_size=5,
#                       activation='relu', input_shape=X_train.shape[-2:]),
#     tf.keras.layers.MaxPooling1D(pool_size=4),
#     tf.keras.layers.Conv1D(filters=32, kernel_size=5, activation='relu'),
#     tf.keras.layers.MaxPooling1D(pool_size=4),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(units=1)
# ])


# rnn_model = tf.keras.Sequential([
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(64, return_sequences=True),
#     tf.keras.layers.SimpleRNN(32, return_sequences=False),
#     tf.keras.layers.Dense(units=1)
# ])


# autoregressive_model = tf.keras.Sequential([
#     tf.keras.layers.Dense(units=1, input_shape=X_train.shape[-2:])
# ])

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint("biLSTM" + ".keras", save_best_only=True) # add the .keras extension to the filepath


bi_LSTM_history = compile_and_fit(bi_lstm_model, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="biLSTM", patience=PAT)
loss_by_epoch["biLSTM"] = bi_LSTM_history.history
val_performance["biLSTM"] = bi_lstm_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["biLSTM"] = bi_lstm_model.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 47ms/step - loss: 0.0437 - mean_absolute_error: 0.1583 - mean_absolute_percentage_error: 2750.7961 - mean_squared_error: 0.0437 - val_loss: 0.0290 - val_mean_absolute_error: 0.1442 - val_mean_absolute_percentage_error: 40.7198 - val_mean_squared_error: 0.0290
# Epoch 2/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0103 - mean_absolute_error: 0.0790 - mean_absolute_percentage_error: 2232.3125 - mean_squared_error: 0.0103 - val_loss: 0.0541 - val_mean_absolute_error: 0.1853 - val_mean_absolute_percentage_error: 45.4705 - val_mean_squared_error: 0.0541
# Epoch 3/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0130 - mean_absolute_error: 0.0873 - mean_absolute_percentage_error: 2226.2048 - mean_squared_error: 0.0130 - val_loss: 0.1571 - val_mean_absolute_error: 0.3327 - val_mean_absolute_percentage_error: 81.2021 - val_mean_squared_error: 0.1571
# Epoch 4/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0160 - mean_absolute_error: 0.1014 - mean_absolute_percentage_error: 2753.5464 - mean_squared_error: 0.0160 - val_loss: 0.0360 - val_mean_absolute_error: 0.1548 - val_mean_absolute_percentage_error: 36.9093 - val_mean_squared_error: 0.0360
# Epoch 5/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - loss: 0.0145 - mean_absolute_error: 0.0938 - mean_absolute_percentage_error: 2694.3291 - mean_squared_error: 0.0145 - val_loss: 0.0138 - val_mean_absolute_error: 0.0913 - val_mean_absolute_percentage_error: 21.9907 - val_mean_squared_error: 0.0138
# Epoch 6/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0102 - mean_absolute_error: 0.0780 - mean_absolute_percentage_error: 2612.9207 - mean_squared_error: 0.0102 - val_loss: 0.0228 - val_mean_absolute_error: 0.1252 - val_mean_absolute_percentage_error: 34.8184 - val_mean_squared_error: 0.0228
# Epoch 7/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0085 - mean_absolute_error: 0.0712 - mean_absolute_percentage_error: 2366.5767 - mean_squared_error: 0.0085 - val_loss: 0.0442 - val_mean_absolute_error: 0.1652 - val_mean_absolute_percentage_error: 47.5616 - val_mean_squared_error: 0.0442
# Epoch 8/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - loss: 0.0105 - mean_absolute_error: 0.0810 - mean_absolute_percentage_error: 2678.3325 - mean_squared_error: 0.0105 - val_loss: 0.0377 - val_mean_absolute_error: 0.1676 - val_mean_absolute_percentage_error: 46.1314 - val_mean_squared_error: 0.0377
# Epoch 9/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0119 - mean_absolute_error: 0.0824 - mean_absolute_percentage_error: 2763.3381 - mean_squared_error: 0.0119 - val_loss: 0.0191 - val_mean_absolute_error: 0.1155 - val_mean_absolute_percentage_error: 27.5761 - val_mean_squared_error: 0.0191
# Epoch 10/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - loss: 0.0096 - mean_absolute_error: 0.0746 - mean_absolute_percentage_error: 3054.8884 - mean_squared_error: 0.0096 - val_loss: 0.0068 - val_mean_absolute_error: 0.0515 - val_mean_absolute_percentage_error: 10.6465 - val_mean_squared_error: 0.0068
# Epoch 11/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0059 - mean_absolute_error: 0.0531 - mean_absolute_percentage_error: 2377.2537 - mean_squared_error: 0.0059 - val_loss: 0.0070 - val_mean_absolute_error: 0.0500 - val_mean_absolute_percentage_error: 10.3817 - val_mean_squared_error: 0.0070
# Epoch 12/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0042 - mean_absolute_error: 0.0407 - mean_absolute_percentage_error: 2071.0181 - mean_squared_error: 0.0042 - val_loss: 0.0084 - val_mean_absolute_error: 0.0654 - val_mean_absolute_percentage_error: 13.9985 - val_mean_squared_error: 0.0084
# Epoch 13/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 0.0042 - mean_absolute_error: 0.0425 - mean_absolute_percentage_error: 2018.6864 - mean_squared_error: 0.0042 - val_loss: 0.0161 - val_mean_absolute_error: 0.0993 - val_mean_absolute_percentage_error: 21.8859 - val_mean_squared_error: 0.0161
# Epoch 14/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - loss: 0.0058 - mean_absolute_error: 0.0515 - mean_absolute_percentage_error: 2419.1250 - mean_squared_error: 0.0058 - val_loss: 0.0181 - val_mean_absolute_error: 0.1136 - val_mean_absolute_percentage_error: 30.0638 - val_mean_squared_error: 0.0181
# Epoch 15/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0065 - mean_absolute_error: 0.0581 - mean_absolute_percentage_error: 2497.1096 - mean_squared_error: 0.0065 - val_loss: 0.0246 - val_mean_absolute_error: 0.1324 - val_mean_absolute_percentage_error: 36.2761 - val_mean_squared_error: 0.0246
# Epoch 16/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0073 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 2715.3152 - mean_squared_error: 0.0073 - val_loss: 0.0530 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 54.4417 - val_mean_squared_error: 0.0530
# Epoch 17/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0106 - mean_absolute_error: 0.0810 - mean_absolute_percentage_error: 2670.3555 - mean_squared_error: 0.0106 - val_loss: 0.0190 - val_mean_absolute_error: 0.1064 - val_mean_absolute_percentage_error: 29.0969 - val_mean_squared_error: 0.0190
# Epoch 18/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 0.0076 - mean_absolute_error: 0.0637 - mean_absolute_percentage_error: 2610.3381 - mean_squared_error: 0.0076 - val_loss: 0.0153 - val_mean_absolute_error: 0.1000 - val_mean_absolute_percentage_error: 27.6128 - val_mean_squared_error: 0.0153
# Epoch 19/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0064 - mean_absolute_error: 0.0606 - mean_absolute_percentage_error: 2337.6584 - mean_squared_error: 0.0064 - val_loss: 0.0104 - val_mean_absolute_error: 0.0702 - val_mean_absolute_percentage_error: 15.8988 - val_mean_squared_error: 0.0104
# Epoch 20/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0042 - mean_absolute_error: 0.0413 - mean_absolute_percentage_error: 2254.0315 - mean_squared_error: 0.0042 - val_loss: 0.0066 - val_mean_absolute_error: 0.0499 - val_mean_absolute_percentage_error: 9.9564 - val_mean_squared_error: 0.0066
# Epoch 21/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0036 - mean_absolute_error: 0.0378 - mean_absolute_percentage_error: 2372.0896 - mean_squared_error: 0.0036 - val_loss: 0.0070 - val_mean_absolute_error: 0.0536 - val_mean_absolute_percentage_error: 10.8085 - val_mean_squared_error: 0.0070
# Epoch 22/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0036 - mean_absolute_error: 0.0378 - mean_absolute_percentage_error: 2393.4719 - mean_squared_error: 0.0036 - val_loss: 0.0075 - val_mean_absolute_error: 0.0610 - val_mean_absolute_percentage_error: 13.0900 - val_mean_squared_error: 0.0075
# Epoch 23/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0037 - mean_absolute_error: 0.0388 - mean_absolute_percentage_error: 2528.7556 - mean_squared_error: 0.0037 - val_loss: 0.0076 - val_mean_absolute_error: 0.0666 - val_mean_absolute_percentage_error: 15.2994 - val_mean_squared_error: 0.0076
# Epoch 24/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0039 - mean_absolute_error: 0.0412 - mean_absolute_percentage_error: 2532.1118 - mean_squared_error: 0.0039 - val_loss: 0.0142 - val_mean_absolute_error: 0.1018 - val_mean_absolute_percentage_error: 26.5383 - val_mean_squared_error: 0.0142
# Epoch 25/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0051 - mean_absolute_error: 0.0506 - mean_absolute_percentage_error: 2270.4888 - mean_squared_error: 0.0051 - val_loss: 0.0161 - val_mean_absolute_error: 0.1079 - val_mean_absolute_percentage_error: 28.9036 - val_mean_squared_error: 0.0161
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0196 - mean_absolute_error: 0.1261 - mean_absolute_percentage_error: 35.1248 - mean_squared_error: 0.0196

# %%
plot_single_pred(bi_lstm_model,'BiLSTM', test_dataset, test_steps, y_test, batch_size=1)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'Predictions': array([0.6887761 , 0.6842384 , 0.68025196, ..., 0.32310048, 0.31725514,
#         0.30990642], dtype=float32),
#  'Actual': array([0.57619943, 0.57948471, 0.57948471, ..., 0.74703377, 0.73717794,
#         0.73060739])}

# %%
import matplotlib.pyplot as plt

# plotting training vs validation loss
history = bi_LSTM_history.history

plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint("LSTM" + ".keras", save_best_only=True) # add the .keras extension to the filepath


LSTM_history = compile_and_fit(lstm_model, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="LSTM", patience=PAT)
loss_by_epoch["LSTM"] = LSTM_history.history
val_performance["LSTM"] = lstm_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["LSTM"] = lstm_model.evaluate
# Out:
# Epoch 1/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.0352 - mean_absolute_error: 0.1440 - mean_absolute_percentage_error: 2478.8262 - mean_squared_error: 0.0352 - val_loss: 0.0135 - val_mean_absolute_error: 0.1003 - val_mean_absolute_percentage_error: 25.0349 - val_mean_squared_error: 0.0135
# Epoch 2/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0087 - mean_absolute_error: 0.0703 - mean_absolute_percentage_error: 1587.0127 - mean_squared_error: 0.0087 - val_loss: 0.0257 - val_mean_absolute_error: 0.1293 - val_mean_absolute_percentage_error: 33.8898 - val_mean_squared_error: 0.0257
# Epoch 3/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0110 - mean_absolute_error: 0.0818 - mean_absolute_percentage_error: 1587.6488 - mean_squared_error: 0.0110 - val_loss: 0.0287 - val_mean_absolute_error: 0.1363 - val_mean_absolute_percentage_error: 31.6470 - val_mean_squared_error: 0.0287
# Epoch 4/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0129 - mean_absolute_error: 0.0870 - mean_absolute_percentage_error: 2072.4707 - mean_squared_error: 0.0129 - val_loss: 0.0213 - val_mean_absolute_error: 0.1141 - val_mean_absolute_percentage_error: 27.3922 - val_mean_squared_error: 0.0213
# Epoch 5/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0079 - mean_absolute_error: 0.0662 - mean_absolute_percentage_error: 2731.3489 - mean_squared_error: 0.0079 - val_loss: 0.0304 - val_mean_absolute_error: 0.1455 - val_mean_absolute_percentage_error: 33.2622 - val_mean_squared_error: 0.0304
# Epoch 6/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0624 - mean_absolute_percentage_error: 2855.2173 - mean_squared_error: 0.0074 - val_loss: 0.0236 - val_mean_absolute_error: 0.1240 - val_mean_absolute_percentage_error: 28.0886 - val_mean_squared_error: 0.0236
# Epoch 7/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0090 - mean_absolute_error: 0.0704 - mean_absolute_percentage_error: 2570.1821 - mean_squared_error: 0.0090 - val_loss: 0.0084 - val_mean_absolute_error: 0.0693 - val_mean_absolute_percentage_error: 15.8096 - val_mean_squared_error: 0.0084
# Epoch 8/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0058 - mean_absolute_error: 0.0521 - mean_absolute_percentage_error: 1767.5837 - mean_squared_error: 0.0058 - val_loss: 0.0149 - val_mean_absolute_error: 0.0996 - val_mean_absolute_percentage_error: 24.3579 - val_mean_squared_error: 0.0149
# Epoch 9/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.0080 - mean_absolute_error: 0.0664 - mean_absolute_percentage_error: 1757.6550 - mean_squared_error: 0.0080 - val_loss: 0.0109 - val_mean_absolute_error: 0.0743 - val_mean_absolute_percentage_error: 15.6658 - val_mean_squared_error: 0.0109
# Epoch 10/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0491 - mean_absolute_percentage_error: 2500.5864 - mean_squared_error: 0.0053 - val_loss: 0.0155 - val_mean_absolute_error: 0.0930 - val_mean_absolute_percentage_error: 21.3272 - val_mean_squared_error: 0.0155
# Epoch 11/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0050 - mean_absolute_error: 0.0466 - mean_absolute_percentage_error: 2783.9863 - mean_squared_error: 0.0050 - val_loss: 0.0118 - val_mean_absolute_error: 0.0780 - val_mean_absolute_percentage_error: 17.0963 - val_mean_squared_error: 0.0118
# Epoch 12/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0068 - mean_absolute_error: 0.0588 - mean_absolute_percentage_error: 2320.1724 - mean_squared_error: 0.0068 - val_loss: 0.0166 - val_mean_absolute_error: 0.1062 - val_mean_absolute_percentage_error: 28.0614 - val_mean_squared_error: 0.0166
# Epoch 13/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 1587.0435 - mean_squared_error: 0.0061 - val_loss: 0.0206 - val_mean_absolute_error: 0.1199 - val_mean_absolute_percentage_error: 31.9556 - val_mean_squared_error: 0.0206
# Epoch 14/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0087 - mean_absolute_error: 0.0673 - mean_absolute_percentage_error: 2306.3643 - mean_squared_error: 0.0087 - val_loss: 0.0081 - val_mean_absolute_error: 0.0668 - val_mean_absolute_percentage_error: 15.3496 - val_mean_squared_error: 0.0081
# Epoch 15/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0045 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 2119.4951 - mean_squared_error: 0.0045 - val_loss: 0.0110 - val_mean_absolute_error: 0.0827 - val_mean_absolute_percentage_error: 19.3217 - val_mean_squared_error: 0.0110
# Epoch 16/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0055 - mean_absolute_error: 0.0516 - mean_absolute_percentage_error: 2221.1667 - mean_squared_error: 0.0055 - val_loss: 0.0111 - val_mean_absolute_error: 0.0842 - val_mean_absolute_percentage_error: 19.6280 - val_mean_squared_error: 0.0111
# Epoch 17/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0052 - mean_absolute_error: 0.0485 - mean_absolute_percentage_error: 2337.1936 - mean_squared_error: 0.0052 - val_loss: 0.0090 - val_mean_absolute_error: 0.0731 - val_mean_absolute_percentage_error: 16.3966 - val_mean_squared_error: 0.0090
# Epoch 18/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0042 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 2415.4436 - mean_squared_error: 0.0042 - val_loss: 0.0072 - val_mean_absolute_error: 0.0590 - val_mean_absolute_percentage_error: 12.3614 - val_mean_squared_error: 0.0072
# Epoch 19/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0036 - mean_absolute_error: 0.0358 - mean_absolute_percentage_error: 2517.6870 - mean_squared_error: 0.0036 - val_loss: 0.0061 - val_mean_absolute_error: 0.0423 - val_mean_absolute_percentage_error: 7.9794 - val_mean_squared_error: 0.0061
# Epoch 20/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0033 - mean_absolute_error: 0.0340 - mean_absolute_percentage_error: 2517.4844 - mean_squared_error: 0.0033 - val_loss: 0.0061 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 12.6071 - val_mean_squared_error: 0.0061
# Epoch 21/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0040 - mean_absolute_error: 0.0417 - mean_absolute_percentage_error: 2038.7024 - mean_squared_error: 0.0040 - val_loss: 0.0271 - val_mean_absolute_error: 0.1372 - val_mean_absolute_percentage_error: 36.9820 - val_mean_squared_error: 0.0271
# Epoch 22/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0574 - mean_absolute_percentage_error: 1911.1583 - mean_squared_error: 0.0064 - val_loss: 0.0268 - val_mean_absolute_error: 0.1444 - val_mean_absolute_percentage_error: 35.9420 - val_mean_squared_error: 0.0268
# Epoch 23/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0083 - mean_absolute_error: 0.0665 - mean_absolute_percentage_error: 2366.7563 - mean_squared_error: 0.0083 - val_loss: 0.0171 - val_mean_absolute_error: 0.1109 - val_mean_absolute_percentage_error: 29.1344 - val_mean_squared_error: 0.0171
# Epoch 24/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0063 - mean_absolute_error: 0.0562 - mean_absolute_percentage_error: 2614.5090 - mean_squared_error: 0.0063 - val_loss: 0.0235 - val_mean_absolute_error: 0.1317 - val_mean_absolute_percentage_error: 35.6526 - val_mean_squared_error: 0.0235
# Epoch 25/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0059 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 2729.8933 - mean_squared_error: 0.0059 - val_loss: 0.0100 - val_mean_absolute_error: 0.0821 - val_mean_absolute_percentage_error: 20.0157 - val_mean_squared_error: 0.0100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0114 - mean_absolute_error: 0.0901 - mean_absolute_percentage_error: 22.8082 - mean_squared_error: 0.0114

# %%
plot_single_pred(lstm_model,'LSTM', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'Predictions': array([0.72086036, 0.7204746 , 0.71991616, ..., 0.34929097, 0.3537173 ,
#         0.35726961], dtype=float32),
#  'Actual': array([0.57619943, 0.57948471, 0.57948471, ..., 0.74703377, 0.73717794,
#         0.73060739])}

# %%
import matplotlib.pyplot as plt

# plotting training vs validation loss
history = LSTM_history.history

plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# !pip install keras-self-attention
# Out:
# Requirement already satisfied: keras-self-attention in /usr/local/lib/python3.10/dist-packages (0.51.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-self-attention) (1.26.4)

# %%
# Compile the model
lstm_model_with_attention.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                                  loss='mse',
                                  metrics=['mae', 'mse'])

ckpt = tf.keras.callbacks.ModelCheckpoint("lstmWithSelfAttention" + ".keras", save_best_only=True)

# Train the model using the compile_and_fit function
lstm_with_attention_history = compile_and_fit(lstm_model_with_attention, train_dataset, train_steps, val_dataset, val_steps,
                                              batch_size=BATCH_SIZE, model_name="lstmWithSelfAttention", patience=PAT)
loss_by_epoch["lstmWithSelfAttention"] = lstm_with_attention_history.history

val_performance["lstmWithSelfAttention"] = lstm_model_with_attention.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["lstmWithSelfAttention"] = lstm_model_with_attention.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 26s 77ms/step - loss: 0.0521 - mean_absolute_error: 0.1808 - mean_absolute_percentage_error: 1746.8871 - mean_squared_error: 0.0521 - val_loss: 0.0238 - val_mean_absolute_error: 0.1344 - val_mean_absolute_percentage_error: 35.1741 - val_mean_squared_error: 0.0238
# Epoch 2/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 71ms/step - loss: 0.0196 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 2387.9446 - mean_squared_error: 0.0196 - val_loss: 0.0234 - val_mean_absolute_error: 0.1338 - val_mean_absolute_percentage_error: 35.2959 - val_mean_squared_error: 0.0234
# Epoch 3/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 61ms/step - loss: 0.0177 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 2334.8374 - mean_squared_error: 0.0177 - val_loss: 0.0234 - val_mean_absolute_error: 0.1336 - val_mean_absolute_percentage_error: 35.6447 - val_mean_squared_error: 0.0234
# Epoch 4/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0169 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 2243.0090 - mean_squared_error: 0.0169 - val_loss: 0.0221 - val_mean_absolute_error: 0.1298 - val_mean_absolute_percentage_error: 34.2347 - val_mean_squared_error: 0.0221
# Epoch 5/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 61ms/step - loss: 0.0160 - mean_absolute_error: 0.0991 - mean_absolute_percentage_error: 2290.2151 - mean_squared_error: 0.0160 - val_loss: 0.0201 - val_mean_absolute_error: 0.1236 - val_mean_absolute_percentage_error: 32.1378 - val_mean_squared_error: 0.0201
# Epoch 6/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0152 - mean_absolute_error: 0.0963 - mean_absolute_percentage_error: 2409.7803 - mean_squared_error: 0.0152 - val_loss: 0.0200 - val_mean_absolute_error: 0.1226 - val_mean_absolute_percentage_error: 31.8947 - val_mean_squared_error: 0.0200
# Epoch 7/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - loss: 0.0147 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 2484.8657 - mean_squared_error: 0.0147 - val_loss: 0.0209 - val_mean_absolute_error: 0.1254 - val_mean_absolute_percentage_error: 32.9569 - val_mean_squared_error: 0.0209
# Epoch 8/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - loss: 0.0147 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 2528.0264 - mean_squared_error: 0.0147 - val_loss: 0.0207 - val_mean_absolute_error: 0.1248 - val_mean_absolute_percentage_error: 33.1110 - val_mean_squared_error: 0.0207
# Epoch 9/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0147 - mean_absolute_error: 0.0945 - mean_absolute_percentage_error: 2499.8794 - mean_squared_error: 0.0147 - val_loss: 0.0195 - val_mean_absolute_error: 0.1203 - val_mean_absolute_percentage_error: 31.5510 - val_mean_squared_error: 0.0195
# Epoch 10/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0143 - mean_absolute_error: 0.0927 - mean_absolute_percentage_error: 2450.8064 - mean_squared_error: 0.0143 - val_loss: 0.0181 - val_mean_absolute_error: 0.1152 - val_mean_absolute_percentage_error: 29.5396 - val_mean_squared_error: 0.0181
# Epoch 11/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0136 - mean_absolute_error: 0.0891 - mean_absolute_percentage_error: 2515.0288 - mean_squared_error: 0.0136 - val_loss: 0.0203 - val_mean_absolute_error: 0.1226 - val_mean_absolute_percentage_error: 32.4179 - val_mean_squared_error: 0.0203
# Epoch 12/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0141 - mean_absolute_error: 0.0917 - mean_absolute_percentage_error: 2549.8269 - mean_squared_error: 0.0141 - val_loss: 0.0160 - val_mean_absolute_error: 0.1092 - val_mean_absolute_percentage_error: 27.9708 - val_mean_squared_error: 0.0160
# Epoch 13/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0131 - mean_absolute_error: 0.0880 - mean_absolute_percentage_error: 2643.6687 - mean_squared_error: 0.0131 - val_loss: 0.0153 - val_mean_absolute_error: 0.1051 - val_mean_absolute_percentage_error: 26.5359 - val_mean_squared_error: 0.0153
# Epoch 14/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0123 - mean_absolute_error: 0.0841 - mean_absolute_percentage_error: 2733.9834 - mean_squared_error: 0.0123 - val_loss: 0.0170 - val_mean_absolute_error: 0.1111 - val_mean_absolute_percentage_error: 28.7242 - val_mean_squared_error: 0.0170
# Epoch 15/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0126 - mean_absolute_error: 0.0859 - mean_absolute_percentage_error: 2687.7197 - mean_squared_error: 0.0126 - val_loss: 0.0169 - val_mean_absolute_error: 0.1110 - val_mean_absolute_percentage_error: 28.6090 - val_mean_squared_error: 0.0169
# Epoch 16/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0127 - mean_absolute_error: 0.0866 - mean_absolute_percentage_error: 2693.2080 - mean_squared_error: 0.0127 - val_loss: 0.0164 - val_mean_absolute_error: 0.1086 - val_mean_absolute_percentage_error: 27.8673 - val_mean_squared_error: 0.0164
# Epoch 17/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0126 - mean_absolute_error: 0.0859 - mean_absolute_percentage_error: 2597.2952 - mean_squared_error: 0.0126 - val_loss: 0.0154 - val_mean_absolute_error: 0.1038 - val_mean_absolute_percentage_error: 25.9066 - val_mean_squared_error: 0.0154
# Epoch 18/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - loss: 0.0119 - mean_absolute_error: 0.0831 - mean_absolute_percentage_error: 2629.5676 - mean_squared_error: 0.0119 - val_loss: 0.0154 - val_mean_absolute_error: 0.1040 - val_mean_absolute_percentage_error: 25.9710 - val_mean_squared_error: 0.0154
# Epoch 19/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0116 - mean_absolute_error: 0.0818 - mean_absolute_percentage_error: 2756.8098 - mean_squared_error: 0.0116 - val_loss: 0.0148 - val_mean_absolute_error: 0.1022 - val_mean_absolute_percentage_error: 25.7374 - val_mean_squared_error: 0.0148
# Epoch 20/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 61ms/step - loss: 0.0115 - mean_absolute_error: 0.0811 - mean_absolute_percentage_error: 2759.6619 - mean_squared_error: 0.0115 - val_loss: 0.0159 - val_mean_absolute_error: 0.1060 - val_mean_absolute_percentage_error: 27.0153 - val_mean_squared_error: 0.0159
# Epoch 21/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - loss: 0.0115 - mean_absolute_error: 0.0815 - mean_absolute_percentage_error: 2662.7356 - mean_squared_error: 0.0115 - val_loss: 0.0162 - val_mean_absolute_error: 0.1059 - val_mean_absolute_percentage_error: 26.6837 - val_mean_squared_error: 0.0162
# Epoch 22/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0113 - mean_absolute_error: 0.0806 - mean_absolute_percentage_error: 2645.0742 - mean_squared_error: 0.0113 - val_loss: 0.0152 - val_mean_absolute_error: 0.1025 - val_mean_absolute_percentage_error: 25.8500 - val_mean_squared_error: 0.0152
# Epoch 23/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0112 - mean_absolute_error: 0.0798 - mean_absolute_percentage_error: 2666.6775 - mean_squared_error: 0.0112 - val_loss: 0.0145 - val_mean_absolute_error: 0.1010 - val_mean_absolute_percentage_error: 25.4164 - val_mean_squared_error: 0.0145
# Epoch 24/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0111 - mean_absolute_error: 0.0788 - mean_absolute_percentage_error: 2686.3672 - mean_squared_error: 0.0111 - val_loss: 0.0151 - val_mean_absolute_error: 0.1021 - val_mean_absolute_percentage_error: 25.8741 - val_mean_squared_error: 0.0151
# Epoch 25/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - loss: 0.0110 - mean_absolute_error: 0.0784 - mean_absolute_percentage_error: 2624.3479 - mean_squared_error: 0.0110 - val_loss: 0.0156 - val_mean_absolute_error: 0.1033 - val_mean_absolute_percentage_error: 26.1585 - val_mean_squared_error: 0.0156
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0155 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 29.1502 - mean_squared_error: 0.0155

# %%
plot_single_pred(lstm_model_with_attention,'LSTM with Attention', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# asd
# {'Predictions': array([0.6481661 , 0.6480128 , 0.6479144 , ..., 0.4250353 , 0.42468774,
#         0.42455867], dtype=float32),
#  'Actual': array([0.57619943, 0.57948471, 0.57948471, ..., 0.74703377, 0.73717794,
#         0.73060739])}

# %%
import matplotlib.pyplot as plt

# plotting training vs validation loss
history = lstm_with_attention_history.history

plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint("biLSTMWithSelfAttention" + ".keras", save_best_only=True) # add the .keras extension to the filepath

bi_lstm_model_with_attention_history = compile_and_fit(bi_lstm_model_with_attention, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="biLSTMWithSelfAttention", patience=PAT)
loss_by_epoch["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention_history.history
val_performance["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 35s 85ms/step - loss: 0.0346 - mean_absolute_error: 0.1474 - mean_absolute_percentage_error: 2023.4138 - mean_squared_error: 0.0346 - val_loss: 0.0212 - val_mean_absolute_error: 0.1267 - val_mean_absolute_percentage_error: 32.1940 - val_mean_squared_error: 0.0212
# Epoch 2/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0189 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 2370.1162 - mean_squared_error: 0.0189 - val_loss: 0.0207 - val_mean_absolute_error: 0.1249 - val_mean_absolute_percentage_error: 31.7197 - val_mean_squared_error: 0.0207
# Epoch 3/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0175 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 2464.5964 - mean_squared_error: 0.0175 - val_loss: 0.0193 - val_mean_absolute_error: 0.1206 - val_mean_absolute_percentage_error: 31.1464 - val_mean_squared_error: 0.0193
# Epoch 4/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0162 - mean_absolute_error: 0.1000 - mean_absolute_percentage_error: 2071.8708 - mean_squared_error: 0.0162 - val_loss: 0.0215 - val_mean_absolute_error: 0.1267 - val_mean_absolute_percentage_error: 33.3964 - val_mean_squared_error: 0.0215
# Epoch 5/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0159 - mean_absolute_error: 0.0992 - mean_absolute_percentage_error: 2188.6272 - mean_squared_error: 0.0159 - val_loss: 0.0207 - val_mean_absolute_error: 0.1243 - val_mean_absolute_percentage_error: 32.8899 - val_mean_squared_error: 0.0207
# Epoch 6/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0153 - mean_absolute_error: 0.0966 - mean_absolute_percentage_error: 2179.6907 - mean_squared_error: 0.0153 - val_loss: 0.0245 - val_mean_absolute_error: 0.1336 - val_mean_absolute_percentage_error: 36.1448 - val_mean_squared_error: 0.0245
# Epoch 7/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0151 - mean_absolute_error: 0.0959 - mean_absolute_percentage_error: 2686.9031 - mean_squared_error: 0.0151 - val_loss: 0.0220 - val_mean_absolute_error: 0.1262 - val_mean_absolute_percentage_error: 32.6339 - val_mean_squared_error: 0.0220
# Epoch 8/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0155 - mean_absolute_error: 0.0966 - mean_absolute_percentage_error: 2431.6311 - mean_squared_error: 0.0155 - val_loss: 0.0201 - val_mean_absolute_error: 0.1234 - val_mean_absolute_percentage_error: 32.7921 - val_mean_squared_error: 0.0201
# Epoch 9/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0147 - mean_absolute_error: 0.0950 - mean_absolute_percentage_error: 2107.0312 - mean_squared_error: 0.0147 - val_loss: 0.0267 - val_mean_absolute_error: 0.1386 - val_mean_absolute_percentage_error: 37.9414 - val_mean_squared_error: 0.0267
# Epoch 10/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0149 - mean_absolute_error: 0.0950 - mean_absolute_percentage_error: 2225.3950 - mean_squared_error: 0.0149 - val_loss: 0.0174 - val_mean_absolute_error: 0.1131 - val_mean_absolute_percentage_error: 28.9588 - val_mean_squared_error: 0.0174
# Epoch 11/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0129 - mean_absolute_error: 0.0867 - mean_absolute_percentage_error: 2229.2551 - mean_squared_error: 0.0129 - val_loss: 0.0140 - val_mean_absolute_error: 0.0985 - val_mean_absolute_percentage_error: 23.6779 - val_mean_squared_error: 0.0140
# Epoch 12/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0111 - mean_absolute_error: 0.0786 - mean_absolute_percentage_error: 2280.8181 - mean_squared_error: 0.0111 - val_loss: 0.0118 - val_mean_absolute_error: 0.0892 - val_mean_absolute_percentage_error: 21.1196 - val_mean_squared_error: 0.0118
# Epoch 13/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 79ms/step - loss: 0.0104 - mean_absolute_error: 0.0753 - mean_absolute_percentage_error: 2340.4314 - mean_squared_error: 0.0104 - val_loss: 0.0122 - val_mean_absolute_error: 0.0886 - val_mean_absolute_percentage_error: 20.6926 - val_mean_squared_error: 0.0122
# Epoch 14/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0102 - mean_absolute_error: 0.0735 - mean_absolute_percentage_error: 2494.9780 - mean_squared_error: 0.0102 - val_loss: 0.0119 - val_mean_absolute_error: 0.0843 - val_mean_absolute_percentage_error: 19.3023 - val_mean_squared_error: 0.0119
# Epoch 15/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0096 - mean_absolute_error: 0.0718 - mean_absolute_percentage_error: 2473.7490 - mean_squared_error: 0.0096 - val_loss: 0.0115 - val_mean_absolute_error: 0.0817 - val_mean_absolute_percentage_error: 17.7331 - val_mean_squared_error: 0.0115
# Epoch 16/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0092 - mean_absolute_error: 0.0689 - mean_absolute_percentage_error: 2583.0703 - mean_squared_error: 0.0092 - val_loss: 0.0109 - val_mean_absolute_error: 0.0802 - val_mean_absolute_percentage_error: 18.0233 - val_mean_squared_error: 0.0109
# Epoch 17/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0094 - mean_absolute_error: 0.0701 - mean_absolute_percentage_error: 2621.7444 - mean_squared_error: 0.0094 - val_loss: 0.0119 - val_mean_absolute_error: 0.0797 - val_mean_absolute_percentage_error: 17.4168 - val_mean_squared_error: 0.0119
# Epoch 18/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0089 - mean_absolute_error: 0.0673 - mean_absolute_percentage_error: 2728.4241 - mean_squared_error: 0.0089 - val_loss: 0.0124 - val_mean_absolute_error: 0.0815 - val_mean_absolute_percentage_error: 18.1077 - val_mean_squared_error: 0.0124
# Epoch 19/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0092 - mean_absolute_error: 0.0686 - mean_absolute_percentage_error: 2544.1492 - mean_squared_error: 0.0092 - val_loss: 0.0112 - val_mean_absolute_error: 0.0833 - val_mean_absolute_percentage_error: 19.9471 - val_mean_squared_error: 0.0112
# Epoch 20/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0097 - mean_absolute_error: 0.0712 - mean_absolute_percentage_error: 2371.4968 - mean_squared_error: 0.0097 - val_loss: 0.0140 - val_mean_absolute_error: 0.0977 - val_mean_absolute_percentage_error: 25.2540 - val_mean_squared_error: 0.0140
# Epoch 21/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0103 - mean_absolute_error: 0.0752 - mean_absolute_percentage_error: 2290.7805 - mean_squared_error: 0.0103 - val_loss: 0.0134 - val_mean_absolute_error: 0.0881 - val_mean_absolute_percentage_error: 20.6741 - val_mean_squared_error: 0.0134
# Epoch 22/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0094 - mean_absolute_error: 0.0689 - mean_absolute_percentage_error: 2331.8662 - mean_squared_error: 0.0094 - val_loss: 0.0118 - val_mean_absolute_error: 0.0856 - val_mean_absolute_percentage_error: 20.2324 - val_mean_squared_error: 0.0118
# Epoch 23/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.0098 - mean_absolute_error: 0.0724 - mean_absolute_percentage_error: 2371.4265 - mean_squared_error: 0.0098 - val_loss: 0.0107 - val_mean_absolute_error: 0.0761 - val_mean_absolute_percentage_error: 16.4089 - val_mean_squared_error: 0.0107
# Epoch 24/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0092 - mean_absolute_error: 0.0685 - mean_absolute_percentage_error: 2479.0054 - mean_squared_error: 0.0092 - val_loss: 0.0114 - val_mean_absolute_error: 0.0728 - val_mean_absolute_percentage_error: 15.0379 - val_mean_squared_error: 0.0114
# Epoch 25/25
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.0094 - mean_absolute_error: 0.0690 - mean_absolute_percentage_error: 2504.7412 - mean_squared_error: 0.0094 - val_loss: 0.0152 - val_mean_absolute_error: 0.0944 - val_mean_absolute_percentage_error: 22.5991 - val_mean_squared_error: 0.0152
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0135 - mean_absolute_error: 0.0896 - mean_absolute_percentage_error: 22.7150 - mean_squared_error: 0.0135

# %%
plot_single_pred(bi_lstm_model_with_attention,'BiLSTM with Attention', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# asd
# {'Predictions': array([0.68349344, 0.68323433, 0.6827218 , ..., 0.39241645, 0.3922228 ,
#         0.3919415 ], dtype=float32),
#  'Actual': array([0.57619943, 0.57948471, 0.57948471, ..., 0.74703377, 0.73717794,
#         0.73060739])}

# %%
import matplotlib.pyplot as plt

# plotting training vs validation loss
history = lstm_with_attention_history.history

plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# trying again with differenet activation functions for the attention layer (sigmoid now)
from keras_self_attention import SeqSelfAttention


lstm_model_with_attention = tf.keras.models.Sequential([
    # tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(32, return_sequences=True),  # Set return_sequences=True for attention
    SeqSelfAttention(attention_activation='sigmoid'),  # Add attention layer
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

#biLSTM with an attention layer

bi_lstm_model_with_attention = tf.keras.models.Sequential([
    # tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),  # Set return_sequences=True for attention
    SeqSelfAttention(attention_activation='sigmoid'),  # Add attention layer
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

# %%
# Define the inputs explicitly for more control
#https://www.tensorflow.org/api_docs/python/tf/keras/layers/Attention


inputs = tf.keras.layers.Input(shape=(None, X_train.shape[-1]))

# BiLSTM layers
x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True))(inputs)
x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True))(x)
x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(x)

# attention
attention = tf.keras.layers.Attention()([x, x])

# flatten like before
x = tf.keras.layers.Dense(32, activation='relu')(attention)
outputs = tf.keras.layers.Dense(1, activation='tanh')(x)

# Final model
bi_lstm_model_with_attention = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint("biLSTMWithSelfAttention" + ".keras", save_best_only=True) # add the .keras extension to the filepath

bi_lstm_model_with_attention_history = compile_and_fit(bi_lstm_model_with_attention, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="biLSTMWithSelfAttention", patience=PAT)
loss_by_epoch["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention_history.history
val_performance["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["biLSTMWithSelfAttention"] = bi_lstm_model_with_attention.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)

# %%
plot_single_pred(bi_lstm_model_with_attention,'BiLSTM with Attention', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)

# %%
import matplotlib.pyplot as plt

# plotting training vs validation loss
history = bi_lstm_model_with_attention_history.history

plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Dropout, AdditiveAttention, Permute, Reshape, Multiply, Input, Flatten

# Define the input layer
# https://drlee.io/advanced-stock-pattern-prediction-using-lstm-with-the-attention-mechanism-in-tensorflow-a-step-by-143a2e8b0e95

input_layer = Input(shape=(X_train.shape[1], 1))

# Adding LSTM layers with return_sequences=True
lstm_layer_1 = LSTM(units=50, return_sequences=True)(input_layer)
lstm_layer_2 = LSTM(units=50, return_sequences=True)(lstm_layer_1)

# Self-Attention mechanism
attention_layer = AdditiveAttention(name='attention_weight')([lstm_layer_2, lstm_layer_2])

# Element-wise multiplication to apply attention weights
attention_result = Multiply()([lstm_layer_2, attention_layer])

# Flatten the output to feed into Dense layers
flatten_layer = Flatten()(attention_result)

# Output layer
output_layer = Dense(1)(flatten_layer)

# Final model
lstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile the model
lstm_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                                  loss='mse',
                                  metrics=['mae', 'mse'])

ckpt = tf.keras.callbacks.ModelCheckpoint("lstmWithSelfAttention" + ".keras", save_best_only=True)

# Train the model using the compile_and_fit function
lstm_with_attention_history = compile_and_fit(lstm_model_with_attention, train_dataset, train_steps, val_dataset, val_steps,
                                              batch_size=BATCH_SIZE, model_name="lstmWithSelfAttention", patience=PAT)
loss_by_epoch["lstmWithSelfAttention"] = lstm_with_attention_history.history

val_performance["lstmWithSelfAttention"] = lstm_model_with_attention.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["lstmWithSelfAttention"] = lstm_model_with_attention.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)

# %%
plot_single_pred(lstm_model,'LSTM with Attention', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
