# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]
import pandas as pd
# %matplotlib inline

# %%
# Read and set the index to be the date
df = pd.read_csv('../datasets/TX-Data/met_station/met_1.dat', sep=",", parse_dates=["Date"], index_col="Date")

# pandas remove spaces in the column names
df.columns = df.columns.str.replace(' ','')
df['Ppt'] = df['Ppt'].astype(float)
df['Tair'] = df['Tair'].astype(float)
df['RH'] = df['RH'].astype(float)
df['Windspeed'] = df['Windspeed'].astype(float)
df['Winddirection'] = df['Winddirection'].astype(float)

df
# Out:
#                      Ppt   Tair     RH  Windspeed  Winddirection     Srad
# Date
# 2014-10-01 00:00:00  0.0  22.13  80.70      1.429          203.2     0.00
# 2014-10-01 01:00:00  0.0  21.68  84.70      1.555          201.2     0.00
# 2014-10-01 02:00:00  0.0  22.21  89.20      2.288          193.1     0.00
# 2014-10-01 03:00:00  0.0  22.41  90.00      2.421          195.4     0.00
# 2014-10-01 04:00:00  0.0  22.30  92.60      1.738          191.3     0.00
# ...                  ...    ...    ...        ...            ...      ...
# 2021-08-31 20:00:00  0.0  29.10  60.19      0.610          197.1     0.00
# 2021-08-31 21:00:00  0.0  28.07  62.28      0.510          199.6     0.00
# 2021-08-31 22:00:00  0.0  27.73  63.98      1.417          192.6     0.00
# 2021-08-31 23:00:00  0.0  27.30  67.31      1.741          190.2     0.00
# 2021-09-01 00:00:00  0.0  26.21  74.82      1.617          197.9     0.00
#
# [60649 rows x 6 columns]

# %% [markdown]
# **Date:** Synchronized time stamps (CST)
#
# **Tair:** air temperature (deg C)
#
# **RH:** relative humidity (percentage): https://en.wikipedia.org/wiki/Humidity
#
# **Wind speed:** meters/second
#
# **Wind direction:** Degree
#
# **Srad:** solar radiation (W/m^2) https://en.wikipedia.org/wiki/Solar_irradiance
#
#
#
# These data are a little different from Houston data. But, soil moisture, precipitation, humidity, wind speed and direction and solar radiation are common parameters that we use.

# %%
df.index
# Out:
# DatetimeIndex(['2014-10-01 00:00:00', '2014-10-01 01:00:00',
#                '2014-10-01 02:00:00', '2014-10-01 03:00:00',
#                '2014-10-01 04:00:00', '2014-10-01 05:00:00',
#                '2014-10-01 06:00:00', '2014-10-01 07:00:00',
#                '2014-10-01 08:00:00', '2014-10-01 09:00:00',
#                ...
#                '2021-08-31 15:00:00', '2021-08-31 16:00:00',
#                '2021-08-31 17:00:00', '2021-08-31 18:00:00',
#                '2021-08-31 19:00:00', '2021-08-31 20:00:00',
#                '2021-08-31 21:00:00', '2021-08-31 22:00:00',
#                '2021-08-31 23:00:00', '2021-09-01 00:00:00'],
#               dtype='datetime64[ns]', name='Date', length=60649, freq=None)

# %%
# Docs here https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot
# %matplotlib inline
years = [str(item) for item in range(2015, 2022)]

for i in years:
    df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
    plt.show()
# Out:
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/506986526.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].Tair.resample('D').mean().plot(figsize=(12,6), label="air temperature (deg C)")

# %%
# %matplotlib inline
years = [str(item) for item in range(2015, 2022)]

for i in years:
    df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
    plt.show()
# Out:
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
# /var/folders/dd/wjnc44wn6t3g77ly4h81s60c0000gp/T/ipykernel_9647/4232119221.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df[i].resample('D').mean().plot(figsize=(12,6), y=["Tair", "RH", "Windspeed"])
