# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]
import pandas as pd
# %matplotlib inline

# %%
# Read and set the index to be the date

df = pd.read_csv('../datasets/TX-Data/soil_station/SM_1.dat', sep=",")

# pandas remove spaces in the column names
df.columns = df.columns.str.replace(' ','')
df['SWC_5'] = df['SWC_5'].astype(float)
df['SWC_10'] = df['SWC_10'].astype(float)
df['SWC_20'] = df['SWC_20'].astype(float)
df['SWC_50'] = df['SWC_50'].astype(float)

df['T_5'] = df['T_5'].astype(float)
df['T_10'] = df['T_10'].astype(float)
df['T_20'] = df['T_20'].astype(float)
df['T_50'] = df['T_50'].astype(float)


# Parse the date and set the
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M', errors='coerce')

df = df.set_index('Date')

df
# Out:
#                          Ppt  SWC_5  SWC_10  SWC_20  SWC_50    T_5   T_10  \
# Date
# 2015-01-01 00:00:00     0.00  0.139   0.178   0.148   0.152   2.81   4.40
# 2015-01-01 01:00:00     0.00  0.139   0.178   0.148   0.152   2.86   4.38
# 2015-01-01 02:00:00     0.00  0.139   0.178   0.148   0.152   2.89   4.35
# 2015-01-01 03:00:00     0.00  0.139   0.178   0.148   0.152   2.90   4.33
# 2015-01-01 04:00:00     0.00  0.139   0.178   0.148   0.152   2.96   4.32
# ...                      ...    ...     ...     ...     ...    ...    ...
# 2021-09-30 20:00:00     0.00  0.212   0.176   0.164   0.102  27.27  28.05
# 2021-09-30 21:00:00     0.00  0.212   0.176   0.164   0.102  26.81  27.62
# 2021-09-30 22:00:00     0.00  0.212   0.175   0.164   0.102  26.40  27.26
# 2021-09-30 23:00:00     0.00  0.211   0.175   0.163   0.102  26.06  26.93
# 2021-10-01 00:00:00     0.00  0.211   0.174   0.163   0.102  25.89  26.68
#
#                       T_20   T_50   Flag
# Date
# 2015-01-01 00:00:00   5.77  10.57      3
# 2015-01-01 01:00:00   5.71  10.51      3
# 2015-01-01 02:00:00   5.66  10.47      3
# 2015-01-01 03:00:00   5.62  10.41      3
# 2015-01-01 04:00:00   5.59  10.36      3
# ...                    ...    ...    ...
# 2021-09-30 20:00:00  28.35  28.03      0
# 2021-09-30 21:00:00  28.08  28.05      0
# 2021-09-30 22:00:00  27.84  28.07  12288
# 2021-09-30 23:00:00  27.59  28.09  12288
# 2021-10-01 00:00:00  27.36  28.10  12288
#
# [59161 rows x 10 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-01 00:00:00', '2015-01-01 01:00:00',
#                '2015-01-01 02:00:00', '2015-01-01 03:00:00',
#                '2015-01-01 04:00:00', '2015-01-01 05:00:00',
# 2015-01-01 21:00:00     0.25  0.147   0.178   0.148   0.151  3.77  4.88  5.81
# 2015-01-01 22:00:00     0.00  0.148   0.178   0.148   0.151  3.68  4.83  5.78
# 2015-01-01 23:00:00     0.00  0.149   0.178   0.148   0.151  3.64  4.79  5.74
#
#                       T_50  Flag
# Date
# 2015-01-01 00:00:00  10.57     3
# 2015-01-01 01:00:00  10.51     3
# 2015-01-01 02:00:00  10.47     3
# 2015-01-01 03:00:00  10.41     3
# 2015-01-01 04:00:00  10.36     3
# 2015-01-01 05:00:00  10.32     1
# 2015-01-01 06:00:00  10.27   257
# 2015-01-01 07:00:00  10.22   257
# 2015-01-01 08:00:00  10.17   257
# 2015-01-01 09:00:00  10.12   273
# 2015-01-01 10:00:00  10.08   273
# 2015-01-01 11:00:00  10.03   257
# 2015-01-01 12:00:00   9.99     1
# 2015-01-01 13:00:00   9.95     1
# 2015-01-01 14:00:00   9.90     1
# 2015-01-01 15:00:00   9.86     1
# 2015-01-01 16:00:00   9.82     1
# 2015-01-01 17:00:00   9.79     1
# 2015-01-01 18:00:00   9.77     1
# 2015-01-01 19:00:00   9.75     1
# 2015-01-01 20:00:00   9.74     1
# 2015-01-01 21:00:00   9.72     1
# 2015-01-01 22:00:00   9.71     1
# 2015-01-01 23:00:00   9.69     1

# %%
# Docs here https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot
# %matplotlib inline


df.loc["2015":"2022"].SWC_5.resample('D').mean(numeric_only=True).plot(figsize=(12,6))
plt.savefig("SWC_5-Station-1-All-Years.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %%
# Docs here https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot
# %matplotlib inline
years = [str(item) for item in range(2015, 2022)]

for i in years:
    df.loc[i].SWC_5.resample('D').mean(numeric_only=True).plot(figsize=(12,6))
    plt.savefig("SWC_5-Station-1-Year"+i+".pdf", format="pdf", bbox_inches="tight")

    plt.show()

# %%
# %matplotlib inline
years = [str(item) for item in range(2015, 2022)]

for i in years:
    df.loc[i].resample('D').mean(numeric_only=True).plot(figsize=(12,6), y=["SWC_5", "SWC_10", "SWC_20", "SWC_50"])
    plt.savefig("SWC_5_10_20_50_-Station-1-Year"+i+".pdf", format="pdf", bbox_inches="tight")
    plt.show()

# %%
# %matplotlib inline
years = [str(item) for item in range(2015, 2022)]

for i in years:
    df.loc[i].resample('D').mean(numeric_only=True).plot(figsize=(12,6), y=["T_5", "T_10", "T_20", "T_50"])
    plt.savefig("T_5_10_20_50_-Station-1-Year"+i+".pdf", format="pdf", bbox_inches="tight")

    plt.show()
