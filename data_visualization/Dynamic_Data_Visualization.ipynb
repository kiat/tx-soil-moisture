# %% [markdown]
# # Data Visualization Notebook

# %% [markdown]
# ## 1. Data Loader Function: `load_revised_data`
#
# This function loads the revised final data for a given station.
# The revised data files are located in `../datasets/Revised_Final_Data`.
# The expected file name format is: `Station{station_id}_Revised_Final_Data.csv`.
# It returns a pandas DataFrame with the date parsed as the index.

# %%
# import libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import ipywidgets as widgets
from ipywidgets import interact
from pathlib import Path
from ipywidgets import VBox, HBox, Button, interactive_output

widgets.interactive_output = interactive_output

def load_revised_data(station_id):
    """
    Load revised final data from CSV.
    
    Args:
        station_id (int): Station number (1-6)
        
    Returns:
        pd.DataFrame
    """
    base_dir = Path("../datasets/Revised_Final_Data")
    file_path = base_dir / f"Station{station_id}_Revised_Final_Data.csv"
    # base_dir = Path("../data-cleanup/raw_merged_data")
    # file_path = base_dir / "raw_merged_station_1.csv"
    df = pd.read_csv(file_path, index_col=0, parse_dates=True)
    return df

# %% [markdown]
# ## 2. Soil Moisture Interactive Plot Function: `plot_soil_moisture_interactive`
#
# This function plots soil moisture data for a specified station, year, and month.
# It displays four soil moisture traces corresponding to the columns `SWC_5`, `SWC_10`, `SWC_20`, and `SWC_50`.
# This function calls `fig.show()` to render the Plotly figure directy.

# %%
def plot_soil_moisture_interactive(station_id=1, year=2015, month=1):
    # Load revised data for the selected station
    df = load_revised_data(station_id)
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year and month
    df_filtered = df[(df.index.year == year) & (df.index.month == month)]
    
    if df_filtered.empty:
        print(f"No soil moisture data available for Station {station_id} in {year}-{month:02d}")
        return
    
    # Define the soil moisture columns and colors
    swc_cols = ['SWC_5', 'SWC_10', 'SWC_20', 'SWC_50']
    colors = {
        'SWC_5': '#4682B4',  # blue
        'SWC_10': '#FFA500',  # orange
        'SWC_20': '#3CB371',  # green
        'SWC_50': '#DC143C'   # red
    }
    
    # Create the Plotly figure
    fig = go.Figure()
    for col in swc_cols:
        fig.add_trace(go.Scatter(
            x=df_filtered.index,
            y=df_filtered[col],
            mode='lines',
            name=col,
            line=dict(color=colors[col])
        ))
    
    fig.update_layout(
        title=f"Soil Moisture for Station {station_id} in {year}-{month:02d}",
        xaxis_title="Date",
        yaxis_title="Soil Moisture (m³/m³)",
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 3. Soil Moisture Yearly Plot Function: `plot_soil_moisture_yearly`
#
# This function plots soil moisture data for the entire year for a given station.
# It creates a Plotly figure with the four soil moisture traces and displays the figure using `fig.show()`.

# %%
def plot_soil_moisture_yearly(station_id=1, year=2015):
    """
    Plot soil moisture data for the full selected year.
    
    Args:
        station_id (int): The station number.
        year (int): The selected year.
    """
    # Load revised data for the selected station
    df = load_revised_data(station_id)
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year
    df_filtered = df[df.index.year == year]
    
    if df_filtered.empty:
        print(f"No soil moisture data available for Station {station_id} in {year}")
        return
    
    # Define the soil moisture columns and colors
    swc_cols = ['SWC_5', 'SWC_10', 'SWC_20', 'SWC_50']
    colors = {
        'SWC_5': '#4682B4',   # blue
        'SWC_10': '#FFA500',  # orange
        'SWC_20': '#3CB371',  # green
        'SWC_50': '#DC143C'   # red
    }
    
    # Create the Plotly figure
    fig = go.Figure()
    for col in swc_cols:
        fig.add_trace(go.Scatter(
            x=df_filtered.index,
            y=df_filtered[col],
            mode='lines',
            name=col,
            line=dict(color=colors[col])
        ))
    
    fig.update_layout(
        title=f"Soil Moisture for Station {station_id} in {year}",
        xaxis_title="Date",
        yaxis_title="Soil Moisture (m³/m³)",
        width=1000,
        height=500
    )
    fig.show()

# %%
def plot_soil_moisture_total(station_id=1):
    """
    Plot soil moisture data for the full selected year.
    
    Args:
        station_id (int): The station number.
        year (int): The selected year.
    """
    # Load revised data for the selected station
    df = load_revised_data(station_id)
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year
    df_filtered = df
    
    if df_filtered.empty:
        print(f"No soil moisture data available for Station {station_id}")
        return
    
    # Define the soil moisture columns and colors
    swc_cols = ['SWC_5', 'SWC_10', 'SWC_20', 'SWC_50']
    colors = {
        'SWC_5': '#4682B4',   # blue
        'SWC_10': '#FFA500',  # orange
        'SWC_20': '#3CB371',  # green
        'SWC_50': '#DC143C'   # red
    }
    
    # Create the Plotly figure
    fig = go.Figure()
    for col in swc_cols:
        fig.add_trace(go.Scatter(
            x=df_filtered.index,
            y=df_filtered[col],
            mode='lines',
            name=col,
            line=dict(color=colors[col])
        ))
    
    fig.update_layout(
        title=f"Soil Moisture for Station {station_id}",
        xaxis_title="Date",
        yaxis_title="Soil Moisture (m³/m³)",
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 4. Soil Temperature Interactive Plot Function: `plot_soil_temperature_interactive`
#
# This function plots soil temperature data for a specified station, year, and month.
# It includes four temperature traces: `T_5`, `T_10`, `T_20`, and `T_50`.
# The figure is rendered directly via `fig.show()`.

# %%
def plot_soil_temperature_interactive(station_id=1, year=2015, month=1):
    # Load revised data for the selected station
    df = load_revised_data(station_id)
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year and month
    df_filtered = df[(df.index.year == year) & (df.index.month == month)]
    
    if df_filtered.empty:
        print(f"No soil temperature data available for Station {station_id} in {year}-{month:02d}")
        return
    
    # Define the soil temperature columns and colors
    temp_cols = ['T_5', 'T_10', 'T_20', 'T_50']
    colors = {
        'T_5': '#4682B4',  # blue
        'T_10': '#FFA500',  # orange
        'T_20': '#3CB371',  # green
        'T_50': '#DC143C'   # red
    }
    
    # Create the Plotly figure
    fig = go.Figure()
    for col in temp_cols:
        fig.add_trace(go.Scatter(
            x=df_filtered.index,
            y=df_filtered[col],
            mode='lines',
            name=col,
            line=dict(color=colors[col])
        ))
    
    fig.update_layout(
        title=f"Soil Temperature for Station {station_id} in {year}-{month:02d}",
        xaxis_title="Date",
        yaxis_title="Temperature (°C)",
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 5. Soil Temperature Yearly Plot Function: `plot_soil_temperature_yearly`
#
# This function plots soil temperature data for the entire year for a given station.
# It generates a Plotly figure with the four temperature traces and displays it using `fig.show()`.

# %%
def plot_soil_temperature_yearly(station_id=1, year=2015):
    """
    Plot soil temperature data for the full selected year.
    
    Args:
        station_id (int): The station number.
        year (int): The selected year.
    """
    # Load revised data for the selected station
    df = load_revised_data(station_id)
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year
    df_filtered = df[df.index.year == year]
    
    if df_filtered.empty:
        print(f"No soil temperature data available for Station {station_id} in {year}")
        return
    
    # Define the soil temperature columns and colors
    temp_cols = ['T_5', 'T_10', 'T_20', 'T_50']
    colors = {
        'T_5': '#4682B4',   # blue
        'T_10': '#FFA500',  # orange
        'T_20': '#3CB371',  # green
        'T_50': '#DC143C'   # red
    }
    
    # Create the Plotly figure
    fig = go.Figure()
    for col in temp_cols:
        fig.add_trace(go.Scatter(
            x=df_filtered.index,
            y=df_filtered[col],
            mode='lines',
            name=col,
            line=dict(color=colors[col])
        ))
    
    fig.update_layout(
        title=f"Soil Temperature for Station {station_id} in {year}",
        xaxis_title="Date",
        yaxis_title="Temperature (°C)",
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 6. MET Variable Interactive Plot Function: `plot_met_variable_interactive`
#
# This function plots a specified meteorological variable (e.g., Tair, RH, Wind speed, Srad)
# for a given MET station, year, and month. If available, the station's location (Latitude and Longitude)
# is included in the title. The figure is displayed directly using `fig.show()`.

# %%
def plot_met_variable_interactive(station_id, variable='Tair', year=2015, month=1):
    """
    Plot a MET variable for a specific station, year, and month,
    and include the station's Latitude and Longitude (if available) in the title.
    
    Args:
        station_id (int): The MET station number.
        variable (str): The variable to plot (e.g., 'Tair', 'RH', 'Wind speed', 'Srad').
        year (int): The selected year.
        month (int): The selected month.
    """
    # Load the MET data for the selected station (using your revised data loader)
    df = load_revised_data(station_id)  # or load_cleaned_data if using that function for MET revised files
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year and month
    df_filtered = df[(df.index.year == year) & (df.index.month == month)]
    
    if df_filtered.empty:
        print(f"No meteorological data available for Station {station_id} in {year}-{month:02d}")
        return go.Figure()  # Return an empty figure for consistency
    
    # Get the station location from the first row if available
    if 'Latitude' in df_filtered.columns and 'Longitude' in df_filtered.columns:
        lat = df_filtered['Latitude'].iloc[0]
        lon = df_filtered['Longitude'].iloc[0]
        location_info = f" (Lat: {lat}, Lon: {lon})"
    else:
        location_info = ""
    
    # Create the Plotly figure
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_filtered.index,
        y=df_filtered[variable],
        mode='lines',
        name=variable
    ))
    
    fig.update_layout(
        title=f"{variable} for MET Station {station_id}{location_info} in {year}-{month:02d}",
        xaxis_title="Date",
        yaxis_title=variable,
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 7. MET Variable Yearly Plot Function: `plot_met_variable_yearly`
#
# This function plots a specified meteorological variable for the entire year
# for a given MET station. The station's location is included in the title if available.
# The figure is displayed directly using `fig.show()`.

# %%
def plot_met_variable_yearly(station_id=1, variable='Tair', year=2015):
    """
    Plot the full-year time series for a specified MET variable.
    
    Args:
        station_id (int): The MET station number.
        variable (str): The variable to plot ('Tair', 'RH', 'Windspeed', 'Srad').
        year (int): The selected year.
    """
    # Load the MET data for the selected station
    df = load_revised_data(station_id)  # or load_cleaned_data if that is used for MET revised files
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year
    df_filtered = df[df.index.year == year]
    
    if df_filtered.empty:
        print(f"No {variable} data available for MET Station {station_id} in {year}")
        return go.Figure()  # Return an empty figure if there's no data
    
    # Get the station location if available
    if 'Latitude' in df_filtered.columns and 'Longitude' in df_filtered.columns:
        lat = df_filtered['Latitude'].iloc[0]
        lon = df_filtered['Longitude'].iloc[0]
        location_info = f" (Lat: {lat}, Lon: {lon})"
    else:
        location_info = ""
    
    # Create the Plotly figure
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_filtered.index,
        y=df_filtered[variable],
        mode='lines',
        name=variable,
        line=dict(width=2)
    ))
    
    fig.update_layout(
        title=f"{variable} for MET Station {station_id}{location_info} in {year}",
        xaxis_title="Date",
        yaxis_title=variable,
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# ## 8. MET Variable Comprehensive Plot Function: `plot_met_variable_total`
#
# This function plots a specified meteorological variable for the entire data
# for a given MET station. The station's location is included in the title if available.
# The figure is displayed directly using `fig.show()`.

# %%
def plot_met_variable_total(station_id=1, variable='Tair'):
    """
    Plot the full-year time series for a specified MET variable.
    
    Args:
        station_id (int): The MET station number.
        variable (str): The variable to plot ('Tair', 'RH', 'Windspeed', 'Srad').
        year (int): The selected year.
    """
    # Load the MET data for the selected station
    df = load_revised_data(station_id)  # or load_cleaned_data if that is used for MET revised files
    df.index = pd.to_datetime(df.index)
    
    # Filter data for the selected year
    df_filtered = df
    
    if df_filtered.empty:
        print(f"No {variable} data available for MET Station {station_id}")
        return go.Figure()  # Return an empty figure if there's no data
    
    # Get the station location if available
    if 'Latitude' in df_filtered.columns and 'Longitude' in df_filtered.columns:
        lat = df_filtered['Latitude'].iloc[0]
        lon = df_filtered['Longitude'].iloc[0]
        location_info = f" (Lat: {lat}, Lon: {lon})"
    else:
        location_info = ""
    
    # Create the Plotly figure
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_filtered.index,
        y=df_filtered[variable],
        mode='lines',
        name=variable,
        line=dict(width=2)
    ))
    
    fig.update_layout(
        title=f"{variable} for MET Station {station_id}{location_info}",
        xaxis_title="Date",
        yaxis_title=variable,
        width=1000,
        height=500
    )
    fig.show()

# %% [markdown]
# # 9. Update Plot Function: `update_plot`
#
# This function selects and calls the appropriate plotting function based on the user's selections:
#
# -   **Plot Type:** "Soil Moisture", "Soil Temperature", or "MET Variable"
# -   **Station:** 1–6
# -   **Year:** 2015–2021
# -   **Month:** 1–12 (used only when Time Type is "Monthly")
# -   **MET Variable:** "Tair", "RH", "Windspeed", "Srad"
# -   **Time Type:** "Monthly", "Yearly", "Total"
#
# It then displays the corresponding Plotly figure via the function's internal `fig.show()` call.

# %%
def update_plot(plot_type, station_id, year, month, met_variable, time_resolution):
    if plot_type == "Soil Moisture":
        if time_resolution == "Monthly":
            fig = plot_soil_moisture_interactive(station_id, year, month)
        elif time_resolution == "Yearly":
            fig = plot_soil_moisture_yearly(station_id, year)
        else:
            fig = plot_soil_moisture_total(station_id)
            
    elif plot_type == "Soil Temperature":
        if time_resolution == "Monthly":
            fig = plot_soil_temperature_interactive(station_id, year, month)
        else:
            fig = plot_soil_temperature_yearly(station_id, year)
    elif plot_type == "MET Variable":
        if time_resolution == "Monthly":
            fig = plot_met_variable_interactive(station_id, met_variable, year, month)
        elif time_resolution == "Yearly":
            fig = plot_met_variable_yearly(station_id, met_variable, year)
        else:
            fig = plot_met_variable_total(station_id, met_variable)
    else:
        fig = go.Figure()
    return fig

#############################################
# Create Widgets for the Interface
#############################################
plot_type_selector = widgets.Dropdown(
    options=["Soil Moisture", "Soil Temperature", "MET Variable"],
    value="Soil Moisture",
    description="Plot Type:"
)

station_selector = widgets.Dropdown(
    options=[1, 2, 3, 4, 5, 6],
    value=1,
    description="Station:"
)

year_selector = widgets.Dropdown(
    options=list(range(2015, 2022)),
    value=2015,
    description="Year:"
)

month_selector = widgets.Dropdown(
    options=list(range(1, 13)),
    value=1,
    description="Month:"
)

met_variable_selector = widgets.Dropdown(
    options=['Ppt', 'Tair', 'RH', 'Windspeed', 'Srad'],
    value='Ppt',
    description="MET Var:"
)

time_resolution_selector = widgets.Dropdown(
    options=["Monthly", "Yearly", "Total"],
    value="Monthly",
    description="Time Type:"
)

# Disable the month selector if time resolution is Yearly.
def update_month_visibility(*args):
    if time_resolution_selector.value == "Yearly" or \
       time_resolution_selector.value == "Total":
        month_selector.disabled = True
    else:
        month_selector.disabled = False

def update_year_visibility(*args):
    if time_resolution_selector.value == "Total":
        year_selector.disabled = True
    else:
        year_selector.disabled = False

time_resolution_selector.observe(update_month_visibility, names="value")
time_resolution_selector.observe(update_year_visibility, names="value")

update_month_visibility()  # Initialize based on default value
update_year_visibility()

#############################################
# Create an Interactive Output Area
#############################################
out_fig = interactive_output(update_plot, {
    'plot_type': plot_type_selector,
    'station_id': station_selector,
    'year': year_selector,
    'month': month_selector,
    'met_variable': met_variable_selector,
    'time_resolution': time_resolution_selector
})

ui = VBox([
    HBox([plot_type_selector, station_selector, year_selector, month_selector, met_variable_selector, time_resolution_selector])
])

#############################################
# Display the Interface and Plot
#############################################
display(ui, out_fig)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Plot Type:', options=('Soil Moisture', 'Soil Temperature',…
# Output()
