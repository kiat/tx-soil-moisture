# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# 0 = all messages are logged (default behavior)
# 1 = INFO messages are not printed
# 2 = INFO and WARNING messages are not printed
# 3 = INFO, WARNING, and ERROR messages are not printed

import datetime

import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
#from google.colab import drive
#drive.mount('/content/gdrive')

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

#import warnings
# https://stackoverflow.com/questions/15777951/how-to-suppress-pandas-future-warning
#warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.simplefilter(action='ignore', category=Warning)

tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(0)

import logging
tf.get_logger().setLevel(logging.ERROR)

# https://stackoverflow.com/questions/65697623/tensorflow-warning-found-untraced-functions-such-as-lstm-cell-6-layer-call-and
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Apr 12 17:44:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Reading Data and Data Functions

# %%
import pandas as pd


dfs = {}
for index in range(3, 4):
    # Construct the filename for each iteration
    file_name = 'cleaned_data1-7-' + str(index + 1) + '.csv'
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_name, sep=",", parse_dates=["Date"], index_col="Date")

    # Store the DataFrame in the dictionary with a key for the station
    dfs['Station' + str(index + 1)] = df

# %%
def engineer_data(dfs):
    day = 24 * 60 * 60
    year = 365.2425 * day
    for station, df in dfs.items():
        timestamp_s = (df.index).map(pd.Timestamp.timestamp)
        df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
        df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
        df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
        df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))
        dfs[station] = df

# %%
def scale_data(dfs):
    for station, df in dfs.items():
        cur_df = df.copy()
        d_sin = cur_df.pop("Day sin")
        d_cos = cur_df.pop("Day cos")
        y_sin = cur_df.pop("Year sin")
        y_cos = cur_df.pop("Year cos")
        x = cur_df.pop("x_cord")
        y = cur_df.pop("y_cord")
        z = cur_df.pop("z_cord")
        scaler = MinMaxScaler()
        scaled_df = pd.DataFrame(data=scaler.fit_transform(cur_df), columns=cur_df.columns, index=cur_df.index)
        scaled_df["Day sin"] = d_sin.values
        scaled_df["Day cos"] = d_cos.values
        scaled_df["Year sin"] = y_sin.values
        scaled_df["Year cos"] = y_cos.values
        scaled_df["x_cord"] = x.values
        scaled_df["y_cord"] = y.values
        scaled_df["z_cord"] = z.values
        dfs[station] = scaled_df

# %% [markdown]
# # Batches

# %%
#Definitions
TARGET_COL = "SWC_5"
TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.2
WINDOW_SIZE = 24*7
SHIFT_AMT = 10
PAT = 3
MAX_EPOCHS = 25

# %%
def split(df, target_col=TARGET_COL, train_split = TRAIN_SPLIT, val_split = VAL_SPLIT):
  print(df.columns)
  target_idx = df.columns.get_loc(target_col)
  train_set = df[ : int(len(df) * train_split)].values
  val_set = df[int(len(df) * train_split) : int(len(df) * (train_split + val_split))].values
  test_set = df[int(len(df) * (train_split + val_split)) :].values
  return (train_set, val_set, test_set, target_idx)

# %%
def generate_windows(data, window_size=24*10, shift=24*7, target_idx=0):
    labels = data[:, target_idx]

    X = []
    y = []
    for i in range(len(data) - window_size - shift):
        # get window based on input width
        window = data[i : i + window_size]

        # keep track of label associated with current window
        window_label = labels[i + window_size + shift]

        X.append(window)
        y.append(window_label)

    # in new dataset, each element is a data window, and window label is single value
    return np.array(X), np.array(y)


# given data and its labels, divide the data into batches of size batch_size
def generate_batches(X, y, batch_size=32):
    # divides data into batches, drops any remainder batches smaller than specified batch size.
    # allows models to run with any batch size
    tf_dataset = tf.data.Dataset.from_tensor_slices((X, y))
    tf_dataset = tf_dataset.repeat().batch(batch_size=batch_size, drop_remainder=True)

    # tf_dataset repeats indefinitely, need to compute number of step updates to complete 1 epoch
    steps_per_epoch = len(X) // batch_size

    return (tf_dataset, steps_per_epoch)

# %%
def preprocess_data(df):
    # data cleaning and feature engineering
    train_set, val_set, test_set, target_idx = split(df)


    # create window data for each dataset
    X_train, y_train = generate_windows(train_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)
    X_val, y_val = generate_windows(val_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)
    X_test, y_test = generate_windows(test_set, window_size=WINDOW_SIZE, shift=SHIFT_AMT, target_idx=target_idx)

    return (X_train, y_train, X_val, y_val, X_test, y_test)

# %%
cur_df = dfs["Station4"]

BATCH_SIZE = 128
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data(cur_df)

# divide each dataset into batched version to feed to models
train_dataset, train_steps = generate_batches(X_train, y_train, batch_size=BATCH_SIZE)
val_dataset, val_steps = generate_batches(X_val, y_val, batch_size=BATCH_SIZE)
test_dataset, test_steps = generate_batches(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# Index(['SWC_5', 'SWC_10', 'SWC_20', 'T_5', 'T_10', 'T_20', 'Tair', 'RH',
#        'Srad', 'Ppt', 'Wx', 'Wy', 'Day sin', 'Day cos', 'Year sin', 'Year cos',
#        'Latitude', 'Longitude', 'Sum_Rain_1h', 'Sum_Rain_2h', 'Sum_Rain_5h',
#        'Sum_Rain_10h', 'Sum_Rain_24h', 'Predict_1days_Percentage',
#        'Predict_2days_Percentage', 'Predict_3days_Percentage',
#        'Predict_4days_Percentage', 'Predict_5days_Percentage',
#        'Predict_6days_Percentage', 'Predict_7days_Percentage'],
#       dtype='object')

# %% [markdown]
# # Modeling

# %%
def compile_and_fit(model, data, steps_per_epoch, val_data, val_steps, model_name='model/', patience=3, max_epochs=MAX_EPOCHS, batch_size=32):
    # stop running epochs if the loss stops improving for patience number of epochs
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')

    # store the best model on disk to be loaded later without having to re-fit
    # allows you to load models from disc
    ckpt = tf.keras.callbacks.ModelCheckpoint(model_name, save_best_only=True)

    model.compile(loss=tf.keras.losses.MeanSquaredError(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanSquaredError()])

    history = model.fit(data,
                        epochs=max_epochs,
                        callbacks=[ckpt],
                        validation_data=val_data,
                        validation_steps=val_steps,
                        shuffle=False,
                        batch_size=batch_size,
                        steps_per_epoch = steps_per_epoch)

    return history

# %%
preds = {}

def plot_single_pred(model, name, dataset, data_steps, y, batch_size=32):
    forecast = model.predict(dataset, batch_size=batch_size, steps=data_steps)
    preds[name] = forecast
    if len(forecast.shape) == 3:
        forecast = forecast[:, 0, 0]
    elif len(forecast.shape) == 2:
        forecast = forecast[:, 0]

    plt.figure(figsize=(10, 6))
    plot_data = {"Predictions": forecast, "Actual": y}

    plt.plot(plot_data["Actual"])
    plt.plot(plot_data["Predictions"])

    plt.legend(("Actual", "Predictions"))

    # Save the figure with the model name in the filename
    plt.savefig(f"prediction_{name}.pdf", format='pdf')

    return plot_data

# %%
lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(32, return_sequences=False),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

# %%
bi_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=False)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='tanh'),
])

# %%
loss_by_epoch = {}
val_performance = {}
performance = {}

# %%
history = compile_and_fit(bi_lstm_model, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="biLSTM", patience=PAT)
loss_by_epoch["biLSTM"] = history.history
val_performance["biLSTM"] = bi_lstm_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["biLSTM"] = bi_lstm_model.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 317/317 [==============================] - 56s 145ms/step - loss: 0.0274 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0274 - val_loss: 0.0328 - val_mean_absolute_error: 0.1489 - val_mean_squared_error: 0.0328
# Epoch 2/25
# 317/317 [==============================] - 42s 134ms/step - loss: 0.0208 - mean_absolute_error: 0.1118 - mean_squared_error: 0.0208 - val_loss: 0.0263 - val_mean_absolute_error: 0.1374 - val_mean_squared_error: 0.0263
# Epoch 3/25
# 317/317 [==============================] - 17s 53ms/step - loss: 0.0103 - mean_absolute_error: 0.0782 - mean_squared_error: 0.0103 - val_loss: 0.0312 - val_mean_absolute_error: 0.1376 - val_mean_squared_error: 0.0312
# Epoch 4/25
# 317/317 [==============================] - 42s 133ms/step - loss: 0.0092 - mean_absolute_error: 0.0749 - mean_squared_error: 0.0092 - val_loss: 0.0196 - val_mean_absolute_error: 0.1117 - val_mean_squared_error: 0.0196
# Epoch 5/25
# 317/317 [==============================] - 43s 134ms/step - loss: 0.0076 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0076 - val_loss: 0.0154 - val_mean_absolute_error: 0.0974 - val_mean_squared_error: 0.0154
# Epoch 6/25
# 317/317 [==============================] - 42s 133ms/step - loss: 0.0074 - mean_absolute_error: 0.0645 - mean_squared_error: 0.0074 - val_loss: 0.0144 - val_mean_absolute_error: 0.0982 - val_mean_squared_error: 0.0144
# Epoch 7/25
# 317/317 [==============================] - 42s 134ms/step - loss: 0.0067 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0067 - val_loss: 0.0138 - val_mean_absolute_error: 0.0925 - val_mean_squared_error: 0.0138
# Epoch 8/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0062 - mean_absolute_error: 0.0575 - mean_squared_error: 0.0062 - val_loss: 0.0160 - val_mean_absolute_error: 0.0992 - val_mean_squared_error: 0.0160
# Epoch 9/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0071 - mean_absolute_error: 0.0609 - mean_squared_error: 0.0071 - val_loss: 0.0198 - val_mean_absolute_error: 0.1141 - val_mean_squared_error: 0.0198
# Epoch 10/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0068 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0068 - val_loss: 0.0144 - val_mean_absolute_error: 0.0954 - val_mean_squared_error: 0.0144
# Epoch 11/25
# 317/317 [==============================] - 43s 135ms/step - loss: 0.0051 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0051 - val_loss: 0.0083 - val_mean_absolute_error: 0.0702 - val_mean_squared_error: 0.0083
# Epoch 12/25
# 317/317 [==============================] - 43s 135ms/step - loss: 0.0043 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0043 - val_loss: 0.0082 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0082
# Epoch 13/25
# 317/317 [==============================] - 43s 135ms/step - loss: 0.0034 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0034 - val_loss: 0.0055 - val_mean_absolute_error: 0.0559 - val_mean_squared_error: 0.0055
# Epoch 14/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0030 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0030 - val_loss: 0.0057 - val_mean_absolute_error: 0.0577 - val_mean_squared_error: 0.0057
# Epoch 15/25
# 317/317 [==============================] - 43s 135ms/step - loss: 0.0028 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0028 - val_loss: 0.0050 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0050
# Epoch 16/25
# 317/317 [==============================] - 43s 135ms/step - loss: 0.0027 - mean_absolute_error: 0.0329 - mean_squared_error: 0.0027 - val_loss: 0.0050 - val_mean_absolute_error: 0.0536 - val_mean_squared_error: 0.0050
# Epoch 17/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0026 - mean_absolute_error: 0.0324 - mean_squared_error: 0.0026 - val_loss: 0.0055 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0055
# Epoch 18/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0026 - mean_absolute_error: 0.0323 - mean_squared_error: 0.0026 - val_loss: 0.0057 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0057
# Epoch 19/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0025 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0025 - val_loss: 0.0053 - val_mean_absolute_error: 0.0559 - val_mean_squared_error: 0.0053
# Epoch 20/25
# 317/317 [==============================] - 17s 54ms/step - loss: 0.0025 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0025 - val_loss: 0.0051 - val_mean_absolute_error: 0.0552 - val_mean_squared_error: 0.0051
# Epoch 21/25
# 317/317 [==============================] - 43s 136ms/step - loss: 0.0025 - mean_absolute_error: 0.0309 - mean_squared_error: 0.0025 - val_loss: 0.0048 - val_mean_absolute_error: 0.0526 - val_mean_squared_error: 0.0048
# Epoch 22/25
# 317/317 [==============================] - 17s 55ms/step - loss: 0.0024 - mean_absolute_error: 0.0302 - mean_squared_error: 0.0024 - val_loss: 0.0050 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0050
# Epoch 23/25
# 317/317 [==============================] - 46s 145ms/step - loss: 0.0024 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0024 - val_loss: 0.0048 - val_mean_absolute_error: 0.0530 - val_mean_squared_error: 0.0048
# Epoch 24/25
# 317/317 [==============================] - 44s 137ms/step - loss: 0.0023 - mean_absolute_error: 0.0295 - mean_squared_error: 0.0023 - val_loss: 0.0047 - val_mean_absolute_error: 0.0524 - val_mean_squared_error: 0.0047
# Epoch 25/25
# 317/317 [==============================] - 44s 138ms/step - loss: 0.0023 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0023 - val_loss: 0.0047 - val_mean_absolute_error: 0.0524 - val_mean_squared_error: 0.0047
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0047 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0047

# %%
performance["biLSTM"][1]
# Out:
# 0.05975623428821564

# %%
history = compile_and_fit(lstm_model, train_dataset, train_steps, val_dataset, val_steps, batch_size=BATCH_SIZE, model_name="LSTM", patience=PAT)
loss_by_epoch["LSTM"] = history.history
val_performance["LSTM"] = lstm_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["LSTM"] = lstm_model.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 317/317 [==============================] - 23s 55ms/step - loss: 0.0351 - mean_absolute_error: 0.1470 - mean_squared_error: 0.0351 - val_loss: 0.0380 - val_mean_absolute_error: 0.1515 - val_mean_squared_error: 0.0380
# Epoch 2/25
# 317/317 [==============================] - 15s 49ms/step - loss: 0.0202 - mean_absolute_error: 0.1120 - mean_squared_error: 0.0202 - val_loss: 0.0218 - val_mean_absolute_error: 0.1259 - val_mean_squared_error: 0.0218
# Epoch 3/25
# 317/317 [==============================] - 16s 52ms/step - loss: 0.0087 - mean_absolute_error: 0.0700 - mean_squared_error: 0.0087 - val_loss: 0.0191 - val_mean_absolute_error: 0.1092 - val_mean_squared_error: 0.0191
# Epoch 4/25
# 317/317 [==============================] - 16s 51ms/step - loss: 0.0081 - mean_absolute_error: 0.0671 - mean_squared_error: 0.0081 - val_loss: 0.0152 - val_mean_absolute_error: 0.0998 - val_mean_squared_error: 0.0152
# Epoch 5/25
# 317/317 [==============================] - 16s 49ms/step - loss: 0.0087 - mean_absolute_error: 0.0720 - mean_squared_error: 0.0087 - val_loss: 0.0141 - val_mean_absolute_error: 0.1014 - val_mean_squared_error: 0.0141
# Epoch 6/25
# 317/317 [==============================] - 16s 51ms/step - loss: 0.0071 - mean_absolute_error: 0.0646 - mean_squared_error: 0.0071 - val_loss: 0.0118 - val_mean_absolute_error: 0.0897 - val_mean_squared_error: 0.0118
# Epoch 7/25
# 317/317 [==============================] - 8s 24ms/step - loss: 0.0059 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0059 - val_loss: 0.0123 - val_mean_absolute_error: 0.0885 - val_mean_squared_error: 0.0123
# Epoch 8/25
# 317/317 [==============================] - 8s 24ms/step - loss: 0.0058 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0058 - val_loss: 0.0160 - val_mean_absolute_error: 0.1018 - val_mean_squared_error: 0.0160
# Epoch 9/25
# 317/317 [==============================] - 8s 24ms/step - loss: 0.0064 - mean_absolute_error: 0.0596 - mean_squared_error: 0.0064 - val_loss: 0.0122 - val_mean_absolute_error: 0.0858 - val_mean_squared_error: 0.0122
# Epoch 10/25
# 317/317 [==============================] - 8s 24ms/step - loss: 0.0049 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0049 - val_loss: 0.0126 - val_mean_absolute_error: 0.0895 - val_mean_squared_error: 0.0126
# Epoch 11/25
# 317/317 [==============================] - 16s 51ms/step - loss: 0.0048 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0048 - val_loss: 0.0088 - val_mean_absolute_error: 0.0738 - val_mean_squared_error: 0.0088
# Epoch 12/25
# 317/317 [==============================] - 8s 25ms/step - loss: 0.0039 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0039 - val_loss: 0.0089 - val_mean_absolute_error: 0.0733 - val_mean_squared_error: 0.0089
# Epoch 13/25
# 317/317 [==============================] - 15s 48ms/step - loss: 0.0036 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0036 - val_loss: 0.0071 - val_mean_absolute_error: 0.0642 - val_mean_squared_error: 0.0071
# Epoch 14/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0032 - mean_absolute_error: 0.0383 - mean_squared_error: 0.0032 - val_loss: 0.0069 - val_mean_absolute_error: 0.0636 - val_mean_squared_error: 0.0069
# Epoch 15/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0031 - mean_absolute_error: 0.0369 - mean_squared_error: 0.0031 - val_loss: 0.0066 - val_mean_absolute_error: 0.0615 - val_mean_squared_error: 0.0066
# Epoch 16/25
# 317/317 [==============================] - 15s 49ms/step - loss: 0.0030 - mean_absolute_error: 0.0360 - mean_squared_error: 0.0030 - val_loss: 0.0062 - val_mean_absolute_error: 0.0590 - val_mean_squared_error: 0.0062
# Epoch 17/25
# 317/317 [==============================] - 16s 51ms/step - loss: 0.0028 - mean_absolute_error: 0.0348 - mean_squared_error: 0.0028 - val_loss: 0.0058 - val_mean_absolute_error: 0.0571 - val_mean_squared_error: 0.0058
# Epoch 18/25
# 317/317 [==============================] - 8s 25ms/step - loss: 0.0027 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0027 - val_loss: 0.0059 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0059
# Epoch 19/25
# 317/317 [==============================] - 8s 24ms/step - loss: 0.0026 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0026 - val_loss: 0.0060 - val_mean_absolute_error: 0.0598 - val_mean_squared_error: 0.0060
# Epoch 20/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0026 - mean_absolute_error: 0.0324 - mean_squared_error: 0.0026 - val_loss: 0.0057 - val_mean_absolute_error: 0.0576 - val_mean_squared_error: 0.0057
# Epoch 21/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0319 - mean_squared_error: 0.0025 - val_loss: 0.0052 - val_mean_absolute_error: 0.0544 - val_mean_squared_error: 0.0052
# Epoch 22/25
# 317/317 [==============================] - 15s 49ms/step - loss: 0.0025 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0025 - val_loss: 0.0052 - val_mean_absolute_error: 0.0547 - val_mean_squared_error: 0.0052
# Epoch 23/25
# 317/317 [==============================] - 8s 25ms/step - loss: 0.0024 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0024 - val_loss: 0.0053 - val_mean_absolute_error: 0.0562 - val_mean_squared_error: 0.0053
# Epoch 24/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0024 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0024 - val_loss: 0.0051 - val_mean_absolute_error: 0.0551 - val_mean_squared_error: 0.0051
# Epoch 25/25
# 317/317 [==============================] - 16s 50ms/step - loss: 0.0023 - mean_absolute_error: 0.0294 - mean_squared_error: 0.0023 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516 - val_mean_squared_error: 0.0046
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0046 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0046

# %%
performance["LSTM"][1]
# Out:
# 0.05977194011211395

# %%
plot_single_pred(bi_lstm_model,'BiLSTM', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
# Out:
# 44/44 [==============================] - 3s 22ms/step
# {'Predictions': array([0.4136866 , 0.41312492, 0.41257262, ..., 0.1279555 , 0.12667054,
#         0.12538601], dtype=float32),
#  'Actual': array([0.50282486, 0.5       , 0.5       , ..., 0.11581921, 0.11299435,
#         0.11299435])}

# %%
plot_single_pred(lstm_model,'LSTM', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)
# Out:
# 44/44 [==============================] - 1s 10ms/step
# {'Predictions': array([0.4018137 , 0.39880452, 0.39706033, ..., 0.13499495, 0.1361122 ,
#         0.13602096], dtype=float32),
#  'Actual': array([0.50282486, 0.5       , 0.5       , ..., 0.11581921, 0.11299435,
#         0.11299435])}

# %% [markdown]
# #Feed Back Models

# %%
class BiFeedBack(tf.keras.Model):
    def __init__(self, units, out_steps, num_features):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        # Use a Bidirectional LSTM layer
        self.bidirectional_lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units, return_sequences=True, return_state=True))
        self.lstm_cell = tf.keras.layers.LSTMCell(units * 2)  # *2 because of concatenation of forward and backward states
        self.dense = tf.keras.layers.Dense(num_features)

    def call(self, inputs, training=None):
        predictions = []

        # Process the input sequence with the bidirectional LSTM.
        x, forward_h, forward_c, backward_h, backward_c = self.bidirectional_lstm(inputs)

        # Concatenate the forward and backward states
        state = [tf.keras.layers.concatenate([forward_h, backward_h]),
                 tf.keras.layers.concatenate([forward_c, backward_c])]

        # Initialize the first input of the generative process with the last output of the bidirectional LSTM
        prediction = self.dense(x[:, -1, :])

        # Insert the first prediction.
        predictions.append(prediction)

        # Run the rest of the prediction steps.
        for n in range(1, self.out_steps):
            x, state = self.lstm_cell(prediction, states=state, training=training)
            prediction = self.dense(x)
            predictions.append(prediction)

        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        return predictions

# %%
class FeedBack(tf.keras.Model):
    def __init__(self, units, out_steps, num_features):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = tf.keras.layers.LSTMCell(units)
        self.lstm_rnn = tf.keras.layers.RNN(self.lstm_cell, return_state=True)
        self.dense = tf.keras.layers.Dense(num_features)

    def call(self, inputs, training=None):
        # Use a TensorArray to capture dynamically unrolled outputs.
        predictions = []

        # Initialize the LSTM state.
        x, *state = self.lstm_rnn(inputs)

        # This is the prediction for the first time step
        prediction = self.dense(x)

        # Insert the first prediction.
        predictions.append(prediction)

        # Run the rest of the prediction steps.
        for n in range(1, self.out_steps):
            # Use the last prediction as input.
            x = prediction
            # Execute one lstm step.
            x, state = self.lstm_cell(x, states=state,
                              training=training)
            # Convert the lstm output to a prediction.
            prediction = self.dense(x)
            # Add the prediction to the output.
            predictions.append(prediction)

        # predictions.shape => (time, batch, features)
        predictions = tf.stack(predictions)
        # predictions.shape => (batch, time, features)
        predictions = tf.transpose(predictions, [1, 0, 2])
        return predictions

# %%
feedback_model = FeedBack(units=128, out_steps=1, num_features=1)

history = compile_and_fit(feedback_model, train_dataset, train_steps, val_dataset, val_steps, model_name="Feedback", patience = 5)
loss_by_epoch["Feedback"] = history.history
val_performance["Feedback"] = feedback_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["Feedback"] = feedback_model.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)
# Out:
# Epoch 1/25
# 317/317 [==============================] - 25s 74ms/step - loss: 0.0302 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0302 - val_loss: 0.0300 - val_mean_absolute_error: 0.1412 - val_mean_squared_error: 0.0300
# Epoch 2/25
# 317/317 [==============================] - 23s 73ms/step - loss: 0.0144 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0144 - val_loss: 0.0217 - val_mean_absolute_error: 0.1176 - val_mean_squared_error: 0.0217
# Epoch 3/25
# 317/317 [==============================] - 23s 73ms/step - loss: 0.0124 - mean_absolute_error: 0.0830 - mean_squared_error: 0.0124 - val_loss: 0.0188 - val_mean_absolute_error: 0.1072 - val_mean_squared_error: 0.0188
# Epoch 4/25
# 317/317 [==============================] - 23s 74ms/step - loss: 0.0109 - mean_absolute_error: 0.0773 - mean_squared_error: 0.0109 - val_loss: 0.0138 - val_mean_absolute_error: 0.0845 - val_mean_squared_error: 0.0138
# Epoch 5/25
# 317/317 [==============================] - 22s 69ms/step - loss: 0.0096 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0096 - val_loss: 0.0252 - val_mean_absolute_error: 0.1262 - val_mean_squared_error: 0.0252
# Epoch 6/25
# 317/317 [==============================] - 22s 69ms/step - loss: 0.0098 - mean_absolute_error: 0.0759 - mean_squared_error: 0.0098 - val_loss: 0.0379 - val_mean_absolute_error: 0.1616 - val_mean_squared_error: 0.0379
# Epoch 7/25
# 317/317 [==============================] - 22s 69ms/step - loss: 0.0112 - mean_absolute_error: 0.0797 - mean_squared_error: 0.0112 - val_loss: 0.0366 - val_mean_absolute_error: 0.1575 - val_mean_squared_error: 0.0366
# Epoch 8/25
# 194/317 [=================>............] - ETA: 7s - loss: 0.0125 - mean_absolute_error: 0.0820 - mean_squared_error: 0.0125

# %%
performance["Feedback"][1]

# %%
bi_feedback_model = BiFeedBack(units=128, out_steps=1, num_features=1)

history = compile_and_fit(bi_feedback_model, train_dataset, train_steps, val_dataset, val_steps, model_name="BiFeedback", patience = 5)
loss_by_epoch["BiFeedback"] = history.history
val_performance["BiFeedback"] = bi_feedback_model.evaluate(val_dataset, steps=val_steps, batch_size=BATCH_SIZE, verbose=1)
performance["BiFeedback"] = bi_feedback_model.evaluate(test_dataset, steps=test_steps, batch_size=BATCH_SIZE, verbose=0)

# %%
performance["BiFeedback"][1]

# %%
plot_single_pred(feedback_model, 'Feedback', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)

# %%
plot_single_pred(bi_feedback_model,'BiFeedback', test_dataset, test_steps, y_test, batch_size=BATCH_SIZE)

# %%
lstm_pred = preds["LSTM"][:, 0]
bi_lstm_pred = preds["BiLSTM"][:, 0]
feedback_pred = preds["Feedback"][:, 0, 0]
bi_feedback_pred = preds["BiFeedback"][:, 0, 0]

# %%
print(len(lstm_pred))
print(len(feedback_pred))
print(len(bi_lstm_pred))
print(len(bi_feedback_pred))

# %%
def create_error_table(y):
  data = {
    "LSTM": [mean_squared_error(y, lstm_pred),mean_absolute_error(y, lstm_pred),mean_squared_error(y, lstm_pred, squared = False), mean_absolute_percentage_error(y, lstm_pred)],
    "BiLSTM": [mean_squared_error(y, bi_lstm_pred ),mean_absolute_error(y,bi_lstm_pred ),mean_squared_error(y, bi_lstm_pred , squared = False), mean_absolute_percentage_error(y, bi_lstm_pred )],
    "Feedback": [mean_squared_error(y, feedback_pred),mean_absolute_error(y,feedback_pred),mean_squared_error(y,feedback_pred, squared = False), mean_absolute_percentage_error(y, feedback_pred)],
    "BiFeedback": [mean_squared_error(y, bi_feedback_pred),mean_absolute_error(y, bi_feedback_pred),mean_squared_error(y,bi_feedback_pred, squared = False), mean_absolute_percentage_error(y, bi_feedback_pred)],
  }
  res = pd.DataFrame.from_dict(data, orient='index')
  res.columns = ["MSE", "MAE", "RMSE", "MAPE"]
  return res

# %%
y = y_test[len(y_test)-len(lstm_pred):]

# %%
create_error_table(y)

# %%
drsdfsdf = df['ssdfsdfsdfsd']

# %%
create_error_table(station1)
