# %%
import pandas as pd
import os

# 1.What files are in  directory to make sure the path is right
data_dir = "datasets/New_Revised_Final_Data/"
print("Files available:", os.listdir(data_dir))

# 2. Load the very first station data
file_path = os.path.join(data_dir, "Station1_filled_Data.csv")
df = pd.read_csv(file_path)

# 3. Print the column names so we know exactly what they named the temperature columns
print("\nHere are the exact columns in Station 1:")
print(df.columns.tolist())

# 4. Show the first 3 rows of data to see what it looks like
print("\nFirst few rows of the data:")
print(df.head(3))

# %%
# Check the minimum and maximum temperature values for all depths
print(df[['T_5', 'T_10', 'T_20', 'T_50']].agg(['min', 'max']))
