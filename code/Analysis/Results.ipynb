# %%
#pip install pandas matplotlib scikit-learn numpy
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from analysis_helpers import create_dictionaries_from_csv, interactive_plot, generate_error_table, update_y_true

# %%
n = 4
files = [f"Trial{i}" for i in range(1, n+1)]
results = create_dictionaries_from_csv(files)
results = update_y_true(results)

# %% [markdown]
# TRIAL 1:
#
# Shape:= [Input Size = 24*7, Shift Amount = 24, Batch Size = 1024]
#
# Target:= SWC_5
#
# Station:= Station1

# %%
generate_error_table(results["Trial1"])
# Out:
#             mean_squared_error  mean_absolute_error  \
# column
# ar_bi_lstm            0.020104             0.119277
# shift_bl              0.038962             0.148098
# ar_lstm               0.018804             0.113614
# lstm                  0.008721             0.048935
# bi_lstm               0.007591             0.049964
# cnn                   0.031058             0.148634
#
#             mean_absolute_percentage_error
# column
# ar_bi_lstm                        0.442040
# shift_bl                          0.530778
# ar_lstm                           0.424780
# lstm                              0.123390
# bi_lstm                           0.138450
# cnn                               0.507339

# %%
interactive_plot(results["Trial1"])
# Out:
# ...
# FigureWidget({
#     'data': [{'name': 'ar_bi_lstm',
#               'type': 'scatter',
#               'uid': '8175c608-87b3-4ead-9c4d-01eb42382f72',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.31174907, 0.30815035, 0.30580017, ..., 0.31640178, 0.31547442,
#                           0.31416735])},
#              {'name': 'y_true',
#               'type': 'scatter',
#               'uid': '6876f1c9-4a0c-4228-adff-4e385d5b9ade',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.22180451, 0.22180451, 0.22180451, ..., 0.28947368, 0.28947368,
#                           0.28947368])},
#              {'name': 'shift_bl',
#               'type': 'scatter',
#               'uid': 'a2a294e2-7bc7-4924-a873-306d38059c9d',
#               'visible': True,
# ...

# %% [markdown]
# TRIAL 2:
#
# Shape:= [Input Size = 24*7, Shift Amount = 24, Batch Size = 1024]
#
# Target:= SWC_10
#
# Station:= Station1

# %%
generate_error_table(results["Trial2"])
# Out:
#             mean_squared_error  mean_absolute_error  \
# column
# ar_bi_lstm            0.018117             0.119228
# shift_bl              0.021173             0.097726
# ar_lstm               0.020235             0.121414
# lstm                  0.006329             0.067564
# bi_lstm               0.007352             0.073414
# cnn                   0.020403             0.124087
#
#             mean_absolute_percentage_error
# column
# ar_bi_lstm                        1.598594
# shift_bl                          1.074443
# ar_lstm                           1.796030
# lstm                              0.807888
# bi_lstm                           0.814144
# cnn                               1.394740

# %%
interactive_plot(results["Trial2"])
# Out:
# ...
# FigureWidget({
#     'data': [{'name': 'ar_bi_lstm',
#               'type': 'scatter',
#               'uid': '97ba51db-8661-4e47-b7ba-518fd0a80ce7',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.2661611 , 0.26601622, 0.26362628, ..., 0.27020046, 0.27117136,
#                           0.27029344])},
#              {'name': 'y_true',
#               'type': 'scatter',
#               'uid': '372f1034-551b-4f74-b8cf-77254dc59f2b',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.10747664, 0.10747664, 0.10747664, ..., 0.15420561, 0.14953271,
#                           0.14953271])},
#              {'name': 'shift_bl',
#               'type': 'scatter',
#               'uid': 'caaf59fd-fb0a-4dff-8a79-9bccc3984b3a',
#               'visible': True,
# ...

# %% [markdown]
# TRIAL 3:
#
# Shape:= [Input Size = 24*7, Shift Amount = 24, Batch Size = 1024]
#
# Target:= SWC_20
#
# Station:= Station1

# %%
generate_error_table(results["Trial3"])
# Out:
#             mean_squared_error  mean_absolute_error  \
# column
# ar_bi_lstm            0.017136             0.111070
# shift_bl              0.028327             0.107270
# ar_lstm               0.017426             0.111828
# lstm                  0.005582             0.044801
# bi_lstm               0.004451             0.032263
# cnn                   0.026054             0.134629
#
#             mean_absolute_percentage_error
# column
# ar_bi_lstm                        0.937145
# shift_bl                          0.659643
# ar_lstm                           0.944489
# lstm                              0.323104
# bi_lstm                           0.196056
# cnn                               0.970489

# %%
interactive_plot(results["Trial3"])
# Out:
# ...
# FigureWidget({
#     'data': [{'name': 'ar_bi_lstm',
#               'type': 'scatter',
#               'uid': '0e8bfaa0-13e5-4225-bf01-283045f8ccb1',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.26511073, 0.26602197, 0.26635426, ..., 0.20899089, 0.21183662,
#                           0.21251051])},
#              {'name': 'y_true',
#               'type': 'scatter',
#               'uid': 'e6b1a6f5-aa91-40ab-9897-b01e68335b1d',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.18120805, 0.17449664, 0.17449664, ..., 0.04697987, 0.04697987,
#                           0.04697987])},
#              {'name': 'shift_bl',
#               'type': 'scatter',
#               'uid': '0996ec1d-3969-47e5-a0f3-b37ccec8b36b',
#               'visible': True,
# ...

# %% [markdown]
# TRIAL 4:
#
# Shape:= [Input Size = 24*7, Shift Amount = 24, Batch Size = 1024]
#
# Target:= SWC_50
#
# Station:= Station1

# %%
generate_error_table(results["Trial4"])
# Out:
#             mean_squared_error  mean_absolute_error  \
# column
# ar_bi_lstm            0.006023             0.059426
# shift_bl              0.020544             0.087663
# ar_lstm               0.006075             0.061161
# lstm                  0.002895             0.031739
# bi_lstm               0.002040             0.023095
# cnn                   0.020894             0.118052
#
#             mean_absolute_percentage_error
# column
# ar_bi_lstm                        0.351286
# shift_bl                          0.457978
# ar_lstm                           0.406196
# lstm                              0.155234
# bi_lstm                           0.140186
# cnn                               0.764783

# %%
interactive_plot(results["Trial4"])
# Out:
# ...
# FigureWidget({
#     'data': [{'name': 'ar_bi_lstm',
#               'type': 'scatter',
#               'uid': 'e61ab6ce-e62d-4fd7-b258-318f1c9804dc',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.16438045, 0.16335921, 0.16119832, ..., 0.13377216, 0.13420632,
#                           0.13336259])},
#              {'name': 'y_true',
#               'type': 'scatter',
#               'uid': 'c4a044f4-6c1c-467d-bfd5-a0223cef119a',
#               'visible': True,
#               'x': array([   0,    1,    2, ..., 8189, 8190, 8191]),
#               'y': array([0.09876543, 0.09876543, 0.09876543, ..., 0.07407407, 0.07407407,
#                           0.07407407])},
#              {'name': 'shift_bl',
#               'type': 'scatter',
#               'uid': '51a9e3f1-d2ec-4026-a3e1-3c9e31ce29db',
#               'visible': True,
# ...
